# %%
import pandas as pd
import matplotlib.pyplot as plt
from io import BytesIO
import base64
from IPython.display import display, HTML
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv('team_atts_sp.csv',sep=',')

# %%
df2 = pd.read_csv('team_sp.csv',sep=',')

# %%
df2['team_fifa_api_id'] = df2['team_fifa_api_id'].apply(lambda x: int(x))

# %% [markdown]
# # fusionamos csv's

# %% [markdown]
# ## team_atts_sp con la columna de nombre largo

# %%
df_fus = df.merge(df2[['team_fifa_api_id', 'team_long_name']], on='team_fifa_api_id', how='left')
pd.set_option('display.max_columns', None)

# %% [markdown]
# ## cambiamos los NaN por '<N/A>'

# %%
df_fus = df_fus.fillna(pd.NA)
pd.set_option('display.max_columns', None)

# %% [markdown]
# ## añadimos la columna al final de que año es cada fila

# %%
    df_fus["year"] = pd.to_datetime(df_fus["date"]).dt.year  # Extraer el año de la fecha
    all_years = set(range(df_fus["year"].min(), df_fus["year"].max() + 1))  # Determinar el rango de años

    new_rows = []  # Lista para almacenar nuevas filas
    columnas_extra = [
        "buildUpPlaySpeed", "buildUpPlaySpeedClass", "buildUpPlayDribbling", "buildUpPlayDribblingClass",
        "buildUpPlayPassing", "buildUpPlayPassingClass", "chanceCreationShootingClass", "chanceCreationPositioningClass",
        "defencePressure", "defencePressureClass", "defenceAggression", "defenceAggressionClass",
        "defenceTeamWidth", "defenceTeamWidthClass", "defenceDefenderLineClass"
    ]

    for team in df_fus["team_api_id"].unique():
        team_df = df_fus[df_fus["team_api_id"] == team]  # Filtrar equipo
        existing_years = set(team_df["year"])  # Años existentes del equipo
        missing_years = sorted(all_years - existing_years)[:6 - len(existing_years)]  # Asegurar máx. 6 filas

        # Obtener el team_fifa_api_id correcto para este equipo
        team_fifa_api_id = df_fus.loc[df_fus["team_api_id"] == team, "team_fifa_api_id"].iloc[0]

        for year in missing_years:
            new_row = {col: 0 for col in df_fus.columns if col not in ["date", "team_api_id", "team_fifa_api_id"]}  # Valores en 0
            new_row["team_api_id"] = team
            new_row["team_fifa_api_id"] = team_fifa_api_id  # Mantener el mismo valor
            new_row["date"] = f"{year}-01-01 00:00:00"  # Fecha genérica
            new_row["year"] = year  # Agregar el año auxiliar

            # Asegurar que las columnas adicionales también estén en la nueva fila
            for col in columnas_extra:
                new_row[col] = pd.NA

            new_rows.append(new_row)

    df_missing = pd.DataFrame(new_rows)  # Convertir nuevas filas en DataFrame
    df_final = pd.concat([df_fus, df_missing], ignore_index=True)  # Unir DataFrames
    #df_final = df_final.sort_values(by=["team_api_id", "year"]).drop(columns=["year"])  # Ordenar y eliminar columna auxiliar

df_final
# Out:
#      id  team_fifa_api_id  team_api_id                 date buildUpPlaySpeed  \
# 0    40              1861         9865  2010-02-22 00:00:00               65
# 1    41              1861         9865  2011-02-22 00:00:00               55
# 2    42              1861         9865  2012-02-22 00:00:00               42
# 3    43              1861         9865  2013-09-20 00:00:00               46
# 4    44              1861         9865  2014-09-19 00:00:00               46
# ..   ..               ...          ...                  ...              ...
# 193   0               456         8696  2014-01-01 00:00:00              NaN
# 194   0               260         9867  2012-01-01 00:00:00              NaN
# 195   0               260         9867  2013-01-01 00:00:00              NaN
# 196   0              1742         9868  2014-01-01 00:00:00              NaN
# 197   0              1742         9868  2015-01-01 00:00:00              NaN
#
#     buildUpPlaySpeedClass buildUpPlayDribbling buildUpPlayDribblingClass  \
# 0                Balanced                 <NA>                    Little
# 1                Balanced                 <NA>                    Little
# 2                Balanced                 <NA>                    Little
# 3                Balanced                 <NA>                    Little
# 4                Balanced                 41.0                    Normal
# ..                    ...                  ...                       ...
# 193                   NaN                  NaN                       NaN
# 194                   NaN                  NaN                       NaN
# 195                   NaN                  NaN                       NaN
# 196                   NaN                  NaN                       NaN
# 197                   NaN                  NaN                       NaN
#
#     buildUpPlayPassing buildUpPlayPassingClass buildUpPlayPositioningClass  \
# 0                   45                   Mixed                   Organised
# 1                   53                   Mixed                   Organised
# 2                   70                    Long                   Organised
# 3                   65                   Mixed                   Organised
# 4                   65                   Mixed                   Organised
# ..                 ...                     ...                         ...
# 193                NaN                     NaN                           0
# 194                NaN                     NaN                           0
# 195                NaN                     NaN                           0
# 196                NaN                     NaN                           0
# 197                NaN                     NaN                           0
#
#      chanceCreationPassing chanceCreationPassingClass  chanceCreationCrossing  \
# 0                       45                     Normal                      45
# 1                       57                     Normal                      54
# 2                       57                     Normal                      54
# 3                       57                     Normal                      54
# 4                       57                     Normal                      54
# ..                     ...                        ...                     ...
# 193                      0                          0                       0
# 194                      0                          0                       0
# 195                      0                          0                       0
# 196                      0                          0                       0
# 197                      0                          0                       0
#
#     chanceCreationCrossingClass  chanceCreationShooting  \
# 0                        Normal                      70
# 1                        Normal                      69
# 2                        Normal                      40
# 3                        Normal                      40
# 4                        Normal                      40
# ..                          ...                     ...
# 193                           0                       0
# 194                           0                       0
# 195                           0                       0
# 196                           0                       0
# 197                           0                       0
#
#     chanceCreationShootingClass chanceCreationPositioningClass  \
# 0                          Lots                      Organised
# 1                          Lots                      Organised
# 2                        Normal                      Organised
# 3                        Normal                      Organised
# 4                        Normal                      Organised
# ..                          ...                            ...
# 193                         NaN                            NaN
# 194                         NaN                            NaN
# 195                         NaN                            NaN
# 196                         NaN                            NaN
# 197                         NaN                            NaN
#
#     defencePressure defencePressureClass defenceAggression  \
# 0                70                 High                65
# 1                58               Medium                68
# 2                37               Medium                53
# 3                37               Medium                53
# 4                37               Medium                53
# ..              ...                  ...               ...
# 193             NaN                  NaN               NaN
# 194             NaN                  NaN               NaN
# 195             NaN                  NaN               NaN
# 196             NaN                  NaN               NaN
# 197             NaN                  NaN               NaN
#
#     defenceAggressionClass defenceTeamWidth defenceTeamWidthClass  \
# 0                    Press               30                Narrow
# 1                   Double               67                  Wide
# 2                    Press               45                Normal
# 3                    Press               45                Normal
# 4                    Press               45                Normal
# ..                     ...              ...                   ...
# 193                    NaN              NaN                   NaN
# 194                    NaN              NaN                   NaN
# 195                    NaN              NaN                   NaN
# 196                    NaN              NaN                   NaN
# 197                    NaN              NaN                   NaN
#
#     defenceDefenderLineClass team_long_name  year
# 0                      Cover     UD Almería  2010
# 1                      Cover     UD Almería  2011
# 2                      Cover     UD Almería  2012
# 3                      Cover     UD Almería  2013
# 4                      Cover     UD Almería  2014
# ..                       ...            ...   ...
# 193                      NaN              0  2014
# 194                      NaN              0  2012
# 195                      NaN              0  2013
# 196                      NaN              0  2014
# 197                      NaN              0  2015
#
# [198 rows x 27 columns]

# %% [markdown]
# ## team_atts_sp con el groupby hecho

# %%
df_grb = df_final.groupby('team_fifa_api_id').agg(list)

# %% [markdown]
# # team_atts_sp dejado bonito

# %%
df_grb['team_api_id'] = df_grb['team_api_id'].apply(lambda x: x[0])
df_grb['team_long_name'] = df_grb['team_long_name'].apply(lambda x: x[0])

# %%
s = df_grb['team_long_name']

# %%
df_grb = df_grb.drop(columns = ['team_long_name'])
df_grb.insert(0,'team_long_name', s)

# %% [markdown]
# # team_atts_sp con las columnas por temporada

# %%
# Crear DataFrame de ejemplo con múltiples columnas con listas

df = df_grb[['buildUpPlaySpeed','buildUpPlaySpeedClass','buildUpPlayDribbling','buildUpPlayDribblingClass','buildUpPlayPassing','buildUpPlayPassingClass','buildUpPlayPositioningClass','chanceCreationPassing','chanceCreationPassingClass','chanceCreationCrossing','chanceCreationCrossingClass','chanceCreationShooting','chanceCreationShootingClass','chanceCreationPositioningClass','defencePressure','defencePressureClass','defenceAggression','defenceAggressionClass','defenceTeamWidth','defenceTeamWidthClass','defenceDefenderLineClass']]

# Identificar columnas que contienen listas
columns_to_expand = list(df.columns)#[col for col in df.columns if isinstance(df[col][0], list)]

# Definir nombres de temporadas
temporadas = ["TEMPORADA 09/10", "TEMPORADA 10/11", "TEMPORADA 11/12",
              "TEMPORADA 12/13", "TEMPORADA 13/14", "TEMPORADA 14/15"]

# Función para obtener iniciales en mayúsculas
def obtener_iniciales(nombre):
    a = nombre[0].upper()
    for i in nombre:
        if  i.isupper():
            a = a+i
    return a

# Expandir todas las columnas con listas
#df_reordenado = pd.DataFrame()
#for col in df.columns:
#    df_reordenado[col] = df[col]
#    for col in columns_to_expand:
#        df_expanded = df[col].apply(pd.Series)  # Expande la lista en columnas separadas
#        iniciales = obtener_iniciales(col)  # Obtener iniciales en mayúsculas
#        df_expanded.columns = [f"{iniciales}-{temporadas[i]}" for i in range(df_expanded.shape[1])]  # Renombrar columnas
#        df_final = pd.concat([df_reordenado, df_expanded], axis=1)

# Crear un nuevo DataFrame con el orden correcto
df_reordenado = pd.DataFrame()

# Iterar sobre las columnas del DataFrame original
for col in df.columns:
    df_reordenado[col] = df[col]  # Mantener la columna original
    if col in columns_to_expand:  # Si la columna contiene listas, expandir
        df_expanded = df[col].apply(pd.Series)  # Expandir lista en columnas
        iniciales = obtener_iniciales(col)  # Obtener iniciales
        df_expanded.columns = [f"{iniciales}-{temporadas[i]}" for i in range(df_expanded.shape[1])]  # Renombrar
        df_reordenado = pd.concat([df_reordenado, df_expanded], axis=1)  # Insertar después de la columna original

# Mostrar el resultado
pd.set_option('display.max_columns', None)

#df_reordenado.replace(0,'<N/A>')

# %% [markdown]
# ## añadimos ahora las columnas de nombre largo y el api id

# %%
df_reordenado.insert(0,'team_long_name', s)
df_reordenado.insert(1,'team_api_id', df_grb['team_api_id'])
df_f = df_reordenado
df_f
# Out:
#                              team_long_name  team_api_id  \
# team_fifa_api_id
# 240                         Atlético Madrid         9906
# 241                            FC Barcelona         8634
# 242               RC Deportivo de La Coruña         9783
# 243                          Real Madrid CF         8633
# 244                           Real Zaragoza         8394
# 260                             CD Tenerife         9867
# 448                 Athletic Club de Bilbao         8315
# 449                     Real Betis Balompié         8603
# 450                        RC Celta de Vigo         9910
# 452                            RCD Espanyol         8558
# 453                            RCD Mallorca         8661
# 456                        Racing Santander         8696
# 457                           Real Sociedad         8560
# 459                  Real Sporting de Gijón         9869
# 461                             Valencia CF        10267
# 462                         Real Valladolid        10281
# 467                                SD Eibar         8372
# 468                                Elche CF        10268
# 472                           UD Las Palmas         8306
# 477                             CD Numancia         8388
# 479                              CA Osasuna         8371
# 480                          Rayo Vallecano         8370
# 481                              Sevilla FC         8302
# 483                           Villarreal CF        10205
# 571                           RC Recreativo         8479
# 573                               Málaga CF         9864
# 1742                   Xerez Club Deportivo         9868
# 1853                             Levante UD         8581
# 1860                              Getafe CF         8305
# 1861                             UD Almería         9865
# 1867                             Córdoba CF         7869
# 100879              Hércules Club de Fútbol        10278
# 110832                           Granada CF         7878
#
#                                   buildUpPlaySpeed  BUPS-TEMPORADA 09/10  \
# team_fifa_api_id
# 240                       [64, 57, 47, 47, 47, 57]                    64
# 241                       [42, 43, 24, 35, 35, 36]                    42
# 242                       [30, 56, 56, 56, 56, 53]                    30
# 243                       [55, 54, 45, 50, 50, 50]                    55
# 244                       [30, 43, 34, 38, 38, 52]                    30
# 260                   [30, 56, 56, 56, <NA>, <NA>]                    30
# 448                       [60, 70, 42, 46, 46, 46]                    60
# 449                       [45, 37, 55, 59, 59, 59]                    45
# 450                       [35, 43, 53, 53, 53, 55]                    35
# 452                       [55, 68, 46, 50, 50, 50]                    55
# 453                       [40, 53, 58, 62, 62, 62]                    40
# 456                     [45, 53, 43, 47, 48, <NA>]                    45
# 457                       [40, 54, 24, 28, 35, 60]                    40
# 459                       [70, 68, 51, 55, 55, 55]                    70
# 461                       [30, 41, 20, 20, 30, 35]                    30
# 462                       [55, 54, 55, 55, 55, 43]                    55
# 467               [62, 62, <NA>, <NA>, <NA>, <NA>]                    62
# 468                       [30, 43, 55, 55, 55, 51]                    30
# 472                       [30, 54, 48, 48, 48, 48]                    30
# 477                       [55, 71, 44, 44, 44, 44]                    55
# 479                       [35, 55, 34, 38, 38, 38]                    35
# 480                       [40, 53, 41, 45, 45, 29]                    40
# 481                       [30, 68, 61, 65, 65, 53]                    30
# 483                       [64, 42, 20, 24, 35, 48]                    64
# 571                       [50, 45, 41, 41, 41, 37]                    50
# 573                       [60, 58, 41, 45, 45, 42]                    60
# 1742                  [30, 40, 60, 60, <NA>, <NA>]                    30
# 1853                      [30, 68, 53, 57, 57, 62]                    30
# 1860                      [30, 54, 25, 29, 35, 34]                    30
# 1861                      [65, 55, 42, 46, 46, 46]                    65
# 1867                      [30, 39, 40, 40, 40, 53]                    30
# 100879                  [40, 54, 53, 53, 53, <NA>]                    40
# 110832                  [53, 48, 52, 52, 57, <NA>]                    53
#
#                   BUPS-TEMPORADA 10/11 BUPS-TEMPORADA 11/12  \
# team_fifa_api_id
# 240                                 57                   47
# 241                                 43                   24
# 242                                 56                   56
# 243                                 54                   45
# 244                                 43                   34
# 260                                 56                   56
# 448                                 70                   42
# 449                                 37                   55
# 450                                 43                   53
# 452                                 68                   46
# 453                                 53                   58
# 456                                 53                   43
# 457                                 54                   24
# 459                                 68                   51
# 461                                 41                   20
# 462                                 54                   55
# 467                                 62                 <NA>
# 468                                 43                   55
# 472                                 54                   48
# 477                                 71                   44
# 479                                 55                   34
# 480                                 53                   41
# 481                                 68                   61
# 483                                 42                   20
# 571                                 45                   41
# 573                                 58                   41
# 1742                                40                   60
# 1853                                68                   53
# 1860                                54                   25
# 1861                                55                   42
# 1867                                39                   40
# 100879                              54                   53
# 110832                              48                   52
#
#                  BUPS-TEMPORADA 12/13 BUPS-TEMPORADA 13/14  \
# team_fifa_api_id
# 240                                47                   47
# 241                                35                   35
# 242                                56                   56
# 243                                50                   50
# 244                                38                   38
# 260                                56                 <NA>
# 448                                46                   46
# 449                                59                   59
# 450                                53                   53
# 452                                50                   50
# 453                                62                   62
# 456                                47                   48
# 457                                28                   35
# 459                                55                   55
# 461                                20                   30
# 462                                55                   55
# 467                              <NA>                 <NA>
# 468                                55                   55
# 472                                48                   48
# 477                                44                   44
# 479                                38                   38
# 480                                45                   45
# 481                                65                   65
# 483                                24                   35
# 571                                41                   41
# 573                                45                   45
# 1742                               60                 <NA>
# 1853                               57                   57
# 1860                               29                   35
# 1861                               46                   46
# 1867                               40                   40
# 100879                             53                   53
# 110832                             52                   57
#
#                  BUPS-TEMPORADA 14/15  \
# team_fifa_api_id
# 240                                57
# 241                                36
# 242                                53
# 243                                50
# 244                                52
# 260                              <NA>
# 448                                46
# 449                                59
# 450                                55
# 452                                50
# 453                                62
# 456                              <NA>
# 457                                60
# 459                                55
# 461                                35
# 462                                43
# 467                              <NA>
# 468                                51
# 472                                48
# 477                                44
# 479                                38
# 480                                29
# 481                                53
# 483                                48
# 571                                37
# 573                                42
# 1742                             <NA>
# 1853                               62
# 1860                               34
# 1861                               46
# 1867                               53
# 100879                           <NA>
# 110832                           <NA>
#
#                                               buildUpPlaySpeedClass  \
# team_fifa_api_id
# 240               [Balanced, Balanced, Balanced, Balanced, Balan...
# 241               [Balanced, Balanced, Slow, Balanced, Balanced,...
# 242               [Slow, Balanced, Balanced, Balanced, Balanced,...
# 243               [Balanced, Balanced, Balanced, Balanced, Balan...
# 244               [Slow, Balanced, Balanced, Balanced, Balanced,...
# 260                [Slow, Balanced, Balanced, Balanced, <NA>, <NA>]
# 448               [Balanced, Fast, Balanced, Balanced, Balanced,...
# 449               [Balanced, Balanced, Balanced, Balanced, Balan...
# 450               [Balanced, Balanced, Balanced, Balanced, Balan...
# 452               [Balanced, Fast, Balanced, Balanced, Balanced,...
# 453               [Balanced, Balanced, Balanced, Balanced, Balan...
# 456               [Balanced, Balanced, Balanced, Balanced, Balan...
# 457               [Balanced, Balanced, Slow, Slow, Balanced, Bal...
# 459               [Fast, Fast, Balanced, Balanced, Balanced, Bal...
# 461                    [Slow, Balanced, Slow, Slow, Slow, Balanced]
# 462               [Balanced, Balanced, Balanced, Balanced, Balan...
# 467                    [Balanced, Balanced, <NA>, <NA>, <NA>, <NA>]
# 468               [Slow, Balanced, Balanced, Balanced, Balanced,...
# 472               [Slow, Balanced, Balanced, Balanced, Balanced,...
# 477               [Balanced, Fast, Balanced, Balanced, Balanced,...
# 479               [Balanced, Balanced, Balanced, Balanced, Balan...
# 480               [Balanced, Balanced, Balanced, Balanced, Balan...
# 481               [Slow, Fast, Balanced, Balanced, Balanced, Bal...
# 483               [Balanced, Balanced, Slow, Slow, Balanced, Bal...
# 571               [Balanced, Balanced, Balanced, Balanced, Balan...
# 573               [Balanced, Balanced, Balanced, Balanced, Balan...
# 1742               [Slow, Balanced, Balanced, Balanced, <NA>, <NA>]
# 1853              [Slow, Fast, Balanced, Balanced, Balanced, Bal...
# 1860               [Slow, Balanced, Slow, Slow, Balanced, Balanced]
# 1861              [Balanced, Balanced, Balanced, Balanced, Balan...
# 1867              [Slow, Balanced, Balanced, Balanced, Balanced,...
# 100879            [Balanced, Balanced, Balanced, Balanced, Balan...
# 110832            [Balanced, Balanced, Balanced, Balanced, Balan...
#
#                  BUPSC-TEMPORADA 09/10 BUPSC-TEMPORADA 10/11  \
# team_fifa_api_id
# 240                           Balanced              Balanced
# 241                           Balanced              Balanced
# 242                               Slow              Balanced
# 243                           Balanced              Balanced
# 244                               Slow              Balanced
# 260                               Slow              Balanced
# 448                           Balanced                  Fast
# 449                           Balanced              Balanced
# 450                           Balanced              Balanced
# 452                           Balanced                  Fast
# 453                           Balanced              Balanced
# 456                           Balanced              Balanced
# 457                           Balanced              Balanced
# 459                               Fast                  Fast
# 461                               Slow              Balanced
# 462                           Balanced              Balanced
# 467                           Balanced              Balanced
# 468                               Slow              Balanced
# 472                               Slow              Balanced
# 477                           Balanced                  Fast
# 479                           Balanced              Balanced
# 480                           Balanced              Balanced
# 481                               Slow                  Fast
# 483                           Balanced              Balanced
# 571                           Balanced              Balanced
# 573                           Balanced              Balanced
# 1742                              Slow              Balanced
# 1853                              Slow                  Fast
# 1860                              Slow              Balanced
# 1861                          Balanced              Balanced
# 1867                              Slow              Balanced
# 100879                        Balanced              Balanced
# 110832                        Balanced              Balanced
#
#                  BUPSC-TEMPORADA 11/12 BUPSC-TEMPORADA 12/13  \
# team_fifa_api_id
# 240                           Balanced              Balanced
# 241                               Slow              Balanced
# 242                           Balanced              Balanced
# 243                           Balanced              Balanced
# 244                           Balanced              Balanced
# 260                           Balanced              Balanced
# 448                           Balanced              Balanced
# 449                           Balanced              Balanced
# 450                           Balanced              Balanced
# 452                           Balanced              Balanced
# 453                           Balanced              Balanced
# 456                           Balanced              Balanced
# 457                               Slow                  Slow
# 459                           Balanced              Balanced
# 461                               Slow                  Slow
# 462                           Balanced              Balanced
# 467                               <NA>                  <NA>
# 468                           Balanced              Balanced
# 472                           Balanced              Balanced
# 477                           Balanced              Balanced
# 479                           Balanced              Balanced
# 480                           Balanced              Balanced
# 481                           Balanced              Balanced
# 483                               Slow                  Slow
# 571                           Balanced              Balanced
# 573                           Balanced              Balanced
# 1742                          Balanced              Balanced
# 1853                          Balanced              Balanced
# 1860                              Slow                  Slow
# 1861                          Balanced              Balanced
# 1867                          Balanced              Balanced
# 100879                        Balanced              Balanced
# 110832                        Balanced              Balanced
#
#                  BUPSC-TEMPORADA 13/14 BUPSC-TEMPORADA 14/15  \
# team_fifa_api_id
# 240                           Balanced              Balanced
# 241                           Balanced              Balanced
# 242                           Balanced              Balanced
# 243                           Balanced              Balanced
# 244                           Balanced              Balanced
# 260                               <NA>                  <NA>
# 448                           Balanced              Balanced
# 449                           Balanced              Balanced
# 450                           Balanced              Balanced
# 452                           Balanced              Balanced
# 453                           Balanced              Balanced
# 456                           Balanced                  <NA>
# 457                           Balanced              Balanced
# 459                           Balanced              Balanced
# 461                               Slow              Balanced
# 462                           Balanced              Balanced
# 467                               <NA>                  <NA>
# 468                           Balanced              Balanced
# 472                           Balanced              Balanced
# 477                           Balanced              Balanced
# 479                           Balanced              Balanced
# 480                           Balanced                  Slow
# 481                           Balanced              Balanced
# 483                           Balanced              Balanced
# 571                           Balanced              Balanced
# 573                           Balanced              Balanced
# 1742                              <NA>                  <NA>
# 1853                          Balanced              Balanced
# 1860                          Balanced              Balanced
# 1861                          Balanced              Balanced
# 1867                          Balanced              Balanced
# 100879                        Balanced                  <NA>
# 110832                        Balanced                  <NA>
#
#                                   buildUpPlayDribbling BUPD-TEMPORADA 09/10  \
# team_fifa_api_id
# 240               [<NA>, <NA>, <NA>, <NA>, 52.0, 50.0]                 <NA>
# 241               [<NA>, <NA>, <NA>, <NA>, 35.0, 35.0]                 <NA>
# 242               [<NA>, <NA>, <NA>, <NA>, 55.0, 55.0]                 <NA>
# 243               [<NA>, <NA>, <NA>, <NA>, 54.0, 57.0]                 <NA>
# 244               [<NA>, <NA>, <NA>, <NA>, 48.0, 52.0]                 <NA>
# 260               [<NA>, <NA>, 50.0, 50.0, <NA>, <NA>]                 <NA>
# 448               [<NA>, <NA>, <NA>, <NA>, 41.0, 46.0]                 <NA>
# 449               [<NA>, <NA>, <NA>, <NA>, 49.0, 49.0]                 <NA>
# 450               [<NA>, <NA>, <NA>, <NA>, 54.0, 59.0]                 <NA>
# 452               [<NA>, <NA>, <NA>, <NA>, 52.0, 52.0]                 <NA>
# 453               [<NA>, <NA>, <NA>, <NA>, 53.0, 53.0]                 <NA>
# 456               [<NA>, <NA>, <NA>, <NA>, 52.0, <NA>]                 <NA>
# 457               [<NA>, <NA>, <NA>, <NA>, 52.0, 52.0]                 <NA>
# 459               [<NA>, <NA>, <NA>, <NA>, 48.0, 48.0]                 <NA>
# 461               [<NA>, <NA>, <NA>, <NA>, 45.0, 46.0]                 <NA>
# 462               [<NA>, <NA>, <NA>, <NA>, 44.0, 40.0]                 <NA>
# 467               [51.0, 51.0, <NA>, <NA>, <NA>, <NA>]                 51.0
# 468               [<NA>, <NA>, <NA>, <NA>, 47.0, 52.0]                 <NA>
# 472               [<NA>, <NA>, <NA>, <NA>, 55.0, 55.0]                 <NA>
# 477               [<NA>, <NA>, <NA>, <NA>, 48.0, 48.0]                 <NA>
# 479               [<NA>, <NA>, <NA>, <NA>, 53.0, 53.0]                 <NA>
# 480               [<NA>, <NA>, <NA>, <NA>, 52.0, 52.0]                 <NA>
# 481               [<NA>, <NA>, <NA>, <NA>, 53.0, 53.0]                 <NA>
# 483               [<NA>, <NA>, <NA>, <NA>, 42.0, 42.0]                 <NA>
# 571               [<NA>, <NA>, <NA>, <NA>, 53.0, 38.0]                 <NA>
# 573               [<NA>, <NA>, <NA>, <NA>, 42.0, 51.0]                 <NA>
# 1742              [<NA>, <NA>, <NA>, <NA>, <NA>, <NA>]                 <NA>
# 1853              [<NA>, <NA>, <NA>, <NA>, 51.0, 36.0]                 <NA>
# 1860              [<NA>, <NA>, <NA>, <NA>, 42.0, 41.0]                 <NA>
# 1861              [<NA>, <NA>, <NA>, <NA>, 41.0, 41.0]                 <NA>
# 1867              [<NA>, <NA>, <NA>, <NA>, 53.0, 40.0]                 <NA>
# 100879            [<NA>, <NA>, <NA>, <NA>, 47.0, <NA>]                 <NA>
# 110832            [<NA>, <NA>, <NA>, 62.0, 50.0, <NA>]                 <NA>
#
#                  BUPD-TEMPORADA 10/11 BUPD-TEMPORADA 11/12  \
# team_fifa_api_id
# 240                              <NA>                 <NA>
# 241                              <NA>                 <NA>
# 242                              <NA>                 <NA>
# 243                              <NA>                 <NA>
# 244                              <NA>                 <NA>
# 260                              <NA>                 50.0
# 448                              <NA>                 <NA>
# 449                              <NA>                 <NA>
# 450                              <NA>                 <NA>
# 452                              <NA>                 <NA>
# 453                              <NA>                 <NA>
# 456                              <NA>                 <NA>
# 457                              <NA>                 <NA>
# 459                              <NA>                 <NA>
# 461                              <NA>                 <NA>
# 462                              <NA>                 <NA>
# 467                              51.0                 <NA>
# 468                              <NA>                 <NA>
# 472                              <NA>                 <NA>
# 477                              <NA>                 <NA>
# 479                              <NA>                 <NA>
# 480                              <NA>                 <NA>
# 481                              <NA>                 <NA>
# 483                              <NA>                 <NA>
# 571                              <NA>                 <NA>
# 573                              <NA>                 <NA>
# 1742                             <NA>                 <NA>
# 1853                             <NA>                 <NA>
# 1860                             <NA>                 <NA>
# 1861                             <NA>                 <NA>
# 1867                             <NA>                 <NA>
# 100879                           <NA>                 <NA>
# 110832                           <NA>                 <NA>
#
#                  BUPD-TEMPORADA 12/13 BUPD-TEMPORADA 13/14  \
# team_fifa_api_id
# 240                              <NA>                 52.0
# 241                              <NA>                 35.0
# 242                              <NA>                 55.0
# 243                              <NA>                 54.0
# 244                              <NA>                 48.0
# 260                              50.0                 <NA>
# 448                              <NA>                 41.0
# 449                              <NA>                 49.0
# 450                              <NA>                 54.0
# 452                              <NA>                 52.0
# 453                              <NA>                 53.0
# 456                              <NA>                 52.0
# 457                              <NA>                 52.0
# 459                              <NA>                 48.0
# 461                              <NA>                 45.0
# 462                              <NA>                 44.0
# 467                              <NA>                 <NA>
# 468                              <NA>                 47.0
# 472                              <NA>                 55.0
# 477                              <NA>                 48.0
# 479                              <NA>                 53.0
# 480                              <NA>                 52.0
# 481                              <NA>                 53.0
# 483                              <NA>                 42.0
# 571                              <NA>                 53.0
# 573                              <NA>                 42.0
# 1742                             <NA>                 <NA>
# 1853                             <NA>                 51.0
# 1860                             <NA>                 42.0
# 1861                             <NA>                 41.0
# 1867                             <NA>                 53.0
# 100879                           <NA>                 47.0
# 110832                           62.0                 50.0
#
#                  BUPD-TEMPORADA 14/15  \
# team_fifa_api_id
# 240                              50.0
# 241                              35.0
# 242                              55.0
# 243                              57.0
# 244                              52.0
# 260                              <NA>
# 448                              46.0
# 449                              49.0
# 450                              59.0
# 452                              52.0
# 453                              53.0
# 456                              <NA>
# 457                              52.0
# 459                              48.0
# 461                              46.0
# 462                              40.0
# 467                              <NA>
# 468                              52.0
# 472                              55.0
# 477                              48.0
# 479                              53.0
# 480                              52.0
# 481                              53.0
# 483                              42.0
# 571                              38.0
# 573                              51.0
# 1742                             <NA>
# 1853                             36.0
# 1860                             41.0
# 1861                             41.0
# 1867                             40.0
# 100879                           <NA>
# 110832                           <NA>
#
#                                          buildUpPlayDribblingClass  \
# team_fifa_api_id
# 240               [Little, Little, Little, Little, Normal, Normal]
# 241               [Little, Little, Little, Little, Normal, Normal]
# 242               [Little, Little, Little, Little, Normal, Normal]
# 243               [Little, Little, Little, Little, Normal, Normal]
# 244               [Little, Little, Little, Little, Normal, Normal]
# 260                   [Little, Little, Normal, Normal, <NA>, <NA>]
# 448               [Little, Little, Little, Little, Normal, Normal]
# 449               [Little, Little, Little, Little, Normal, Normal]
# 450               [Little, Little, Little, Little, Normal, Normal]
# 452               [Little, Little, Little, Little, Normal, Normal]
# 453               [Little, Little, Little, Little, Normal, Normal]
# 456                 [Little, Little, Little, Little, Normal, <NA>]
# 457               [Little, Little, Little, Little, Normal, Normal]
# 459               [Little, Little, Little, Little, Normal, Normal]
# 461               [Little, Little, Little, Little, Normal, Normal]
# 462               [Little, Little, Little, Little, Normal, Normal]
# 467                       [Normal, Normal, <NA>, <NA>, <NA>, <NA>]
# 468               [Little, Little, Little, Little, Normal, Normal]
# 472               [Little, Little, Little, Little, Normal, Normal]
# 477               [Little, Little, Little, Little, Normal, Normal]
# 479               [Little, Little, Little, Little, Normal, Normal]
# 480               [Little, Little, Little, Little, Normal, Normal]
# 481               [Little, Little, Little, Little, Normal, Normal]
# 483               [Little, Little, Little, Little, Normal, Normal]
# 571               [Little, Little, Little, Little, Normal, Normal]
# 573               [Little, Little, Little, Little, Normal, Normal]
# 1742                  [Little, Little, Little, Little, <NA>, <NA>]
# 1853              [Little, Little, Little, Little, Normal, Normal]
# 1860              [Little, Little, Little, Little, Normal, Normal]
# 1861              [Little, Little, Little, Little, Normal, Normal]
# 1867              [Little, Little, Little, Little, Normal, Normal]
# 100879              [Little, Little, Little, Little, Normal, <NA>]
# 110832              [Little, Little, Little, Normal, Normal, <NA>]
#
#                  BUPDC-TEMPORADA 09/10 BUPDC-TEMPORADA 10/11  \
# team_fifa_api_id
# 240                             Little                Little
# 241                             Little                Little
# 242                             Little                Little
# 243                             Little                Little
# 244                             Little                Little
# 260                             Little                Little
# 448                             Little                Little
# 449                             Little                Little
# 450                             Little                Little
# 452                             Little                Little
# 453                             Little                Little
# 456                             Little                Little
# 457                             Little                Little
# 459                             Little                Little
# 461                             Little                Little
# 462                             Little                Little
# 467                             Normal                Normal
# 468                             Little                Little
# 472                             Little                Little
# 477                             Little                Little
# 479                             Little                Little
# 480                             Little                Little
# 481                             Little                Little
# 483                             Little                Little
# 571                             Little                Little
# 573                             Little                Little
# 1742                            Little                Little
# 1853                            Little                Little
# 1860                            Little                Little
# 1861                            Little                Little
# 1867                            Little                Little
# 100879                          Little                Little
# 110832                          Little                Little
#
#                  BUPDC-TEMPORADA 11/12 BUPDC-TEMPORADA 12/13  \
# team_fifa_api_id
# 240                             Little                Little
# 241                             Little                Little
# 242                             Little                Little
# 243                             Little                Little
# 244                             Little                Little
# 260                             Normal                Normal
# 448                             Little                Little
# 449                             Little                Little
# 450                             Little                Little
# 452                             Little                Little
# 453                             Little                Little
# 456                             Little                Little
# 457                             Little                Little
# 459                             Little                Little
# 461                             Little                Little
# 462                             Little                Little
# 467                               <NA>                  <NA>
# 468                             Little                Little
# 472                             Little                Little
# 477                             Little                Little
# 479                             Little                Little
# 480                             Little                Little
# 481                             Little                Little
# 483                             Little                Little
# 571                             Little                Little
# 573                             Little                Little
# 1742                            Little                Little
# 1853                            Little                Little
# 1860                            Little                Little
# 1861                            Little                Little
# 1867                            Little                Little
# 100879                          Little                Little
# 110832                          Little                Normal
#
#                  BUPDC-TEMPORADA 13/14 BUPDC-TEMPORADA 14/15  \
# team_fifa_api_id
# 240                             Normal                Normal
# 241                             Normal                Normal
# 242                             Normal                Normal
# 243                             Normal                Normal
# 244                             Normal                Normal
# 260                               <NA>                  <NA>
# 448                             Normal                Normal
# 449                             Normal                Normal
# 450                             Normal                Normal
# 452                             Normal                Normal
# 453                             Normal                Normal
# 456                             Normal                  <NA>
# 457                             Normal                Normal
# 459                             Normal                Normal
# 461                             Normal                Normal
# 462                             Normal                Normal
# 467                               <NA>                  <NA>
# 468                             Normal                Normal
# 472                             Normal                Normal
# 477                             Normal                Normal
# 479                             Normal                Normal
# 480                             Normal                Normal
# 481                             Normal                Normal
# 483                             Normal                Normal
# 571                             Normal                Normal
# 573                             Normal                Normal
# 1742                              <NA>                  <NA>
# 1853                            Normal                Normal
# 1860                            Normal                Normal
# 1861                            Normal                Normal
# 1867                            Normal                Normal
# 100879                          Normal                  <NA>
# 110832                          Normal                  <NA>
#
#                                 buildUpPlayPassing  BUPP-TEMPORADA 09/10  \
# team_fifa_api_id
# 240                       [30, 54, 51, 51, 51, 50]                    30
# 241                       [30, 34, 25, 32, 32, 51]                    30
# 242                       [30, 42, 46, 46, 46, 47]                    30
# 243                       [30, 39, 35, 41, 41, 46]                    30
# 244                       [30, 40, 23, 23, 35, 50]                    30
# 260                   [30, 51, 57, 57, <NA>, <NA>]                    30
# 448                       [45, 69, 59, 38, 38, 39]                    45
# 449                       [45, 51, 37, 37, 37, 37]                    45
# 450                       [30, 44, 62, 62, 62, 38]                    30
# 452                       [40, 55, 44, 44, 44, 44]                    40
# 453                       [40, 52, 57, 57, 57, 57]                    40
# 456                     [55, 56, 44, 44, 47, <NA>]                    55
# 457                       [30, 43, 36, 36, 36, 50]                    30
# 459                       [55, 53, 43, 43, 43, 50]                    55
# 461                       [30, 40, 35, 35, 35, 35]                    30
# 462                       [40, 55, 54, 54, 54, 65]                    40
# 467               [52, 52, <NA>, <NA>, <NA>, <NA>]                    52
# 468                       [30, 39, 73, 73, 69, 48]                    30
# 472                       [30, 56, 44, 44, 44, 44]                    30
# 477                       [40, 53, 45, 45, 45, 45]                    40
# 479                       [35, 54, 52, 52, 52, 52]                    35
# 480                       [30, 55, 44, 44, 44, 44]                    30
# 481                       [30, 58, 65, 65, 65, 53]                    30
# 483                       [30, 41, 26, 26, 35, 36]                    30
# 571                       [40, 58, 54, 54, 54, 43]                    40
# 573                       [55, 54, 36, 36, 36, 36]                    55
# 1742                  [30, 58, 44, 44, <NA>, <NA>]                    30
# 1853                      [30, 56, 63, 63, 63, 65]                    30
# 1860                      [35, 45, 40, 40, 40, 38]                    35
# 1861                      [45, 53, 70, 65, 65, 65]                    45
# 1867                      [30, 41, 53, 53, 53, 48]                    30
# 100879                  [30, 55, 54, 54, 54, <NA>]                    30
# 110832                  [52, 37, 37, 37, 59, <NA>]                    52
#
#                   BUPP-TEMPORADA 10/11 BUPP-TEMPORADA 11/12  \
# team_fifa_api_id
# 240                                 54                   51
# 241                                 34                   25
# 242                                 42                   46
# 243                                 39                   35
# 244                                 40                   23
# 260                                 51                   57
# 448                                 69                   59
# 449                                 51                   37
# 450                                 44                   62
# 452                                 55                   44
# 453                                 52                   57
# 456                                 56                   44
# 457                                 43                   36
# 459                                 53                   43
# 461                                 40                   35
# 462                                 55                   54
# 467                                 52                 <NA>
# 468                                 39                   73
# 472                                 56                   44
# 477                                 53                   45
# 479                                 54                   52
# 480                                 55                   44
# 481                                 58                   65
# 483                                 41                   26
# 571                                 58                   54
# 573                                 54                   36
# 1742                                58                   44
# 1853                                56                   63
# 1860                                45                   40
# 1861                                53                   70
# 1867                                41                   53
# 100879                              55                   54
# 110832                              37                   37
#
#                  BUPP-TEMPORADA 12/13 BUPP-TEMPORADA 13/14  \
# team_fifa_api_id
# 240                                51                   51
# 241                                32                   32
# 242                                46                   46
# 243                                41                   41
# 244                                23                   35
# 260                                57                 <NA>
# 448                                38                   38
# 449                                37                   37
# 450                                62                   62
# 452                                44                   44
# 453                                57                   57
# 456                                44                   47
# 457                                36                   36
# 459                                43                   43
# 461                                35                   35
# 462                                54                   54
# 467                              <NA>                 <NA>
# 468                                73                   69
# 472                                44                   44
# 477                                45                   45
# 479                                52                   52
# 480                                44                   44
# 481                                65                   65
# 483                                26                   35
# 571                                54                   54
# 573                                36                   36
# 1742                               44                 <NA>
# 1853                               63                   63
# 1860                               40                   40
# 1861                               65                   65
# 1867                               53                   53
# 100879                             54                   54
# 110832                             37                   59
#
#                  BUPP-TEMPORADA 14/15  \
# team_fifa_api_id
# 240                                50
# 241                                51
# 242                                47
# 243                                46
# 244                                50
# 260                              <NA>
# 448                                39
# 449                                37
# 450                                38
# 452                                44
# 453                                57
# 456                              <NA>
# 457                                50
# 459                                50
# 461                                35
# 462                                65
# 467                              <NA>
# 468                                48
# 472                                44
# 477                                45
# 479                                52
# 480                                44
# 481                                53
# 483                                36
# 571                                43
# 573                                36
# 1742                             <NA>
# 1853                               65
# 1860                               38
# 1861                               65
# 1867                               48
# 100879                           <NA>
# 110832                           <NA>
#
#                                      buildUpPlayPassingClass  \
# team_fifa_api_id
# 240               [Short, Mixed, Mixed, Mixed, Mixed, Mixed]
# 241               [Short, Mixed, Short, Short, Short, Mixed]
# 242               [Short, Mixed, Mixed, Mixed, Mixed, Mixed]
# 243               [Short, Mixed, Mixed, Mixed, Mixed, Mixed]
# 244               [Short, Mixed, Short, Short, Mixed, Mixed]
# 260                 [Short, Mixed, Mixed, Mixed, <NA>, <NA>]
# 448                [Mixed, Long, Mixed, Mixed, Mixed, Mixed]
# 449               [Mixed, Mixed, Mixed, Mixed, Mixed, Mixed]
# 450               [Short, Mixed, Mixed, Mixed, Mixed, Mixed]
# 452               [Mixed, Mixed, Mixed, Mixed, Mixed, Mixed]
# 453               [Mixed, Mixed, Mixed, Mixed, Mixed, Mixed]
# 456                [Mixed, Mixed, Mixed, Mixed, Mixed, <NA>]
# 457               [Short, Mixed, Mixed, Mixed, Mixed, Mixed]
# 459               [Mixed, Mixed, Mixed, Mixed, Mixed, Mixed]
# 461               [Short, Mixed, Mixed, Mixed, Mixed, Mixed]
# 462               [Mixed, Mixed, Mixed, Mixed, Mixed, Mixed]
# 467                   [Mixed, Mixed, <NA>, <NA>, <NA>, <NA>]
# 468                  [Short, Mixed, Long, Long, Long, Mixed]
# 472               [Short, Mixed, Mixed, Mixed, Mixed, Mixed]
# 477               [Mixed, Mixed, Mixed, Mixed, Mixed, Mixed]
# 479               [Mixed, Mixed, Mixed, Mixed, Mixed, Mixed]
# 480               [Short, Mixed, Mixed, Mixed, Mixed, Mixed]
# 481               [Short, Mixed, Mixed, Mixed, Mixed, Mixed]
# 483               [Short, Mixed, Short, Short, Mixed, Mixed]
# 571               [Mixed, Mixed, Mixed, Mixed, Mixed, Mixed]
# 573               [Mixed, Mixed, Mixed, Mixed, Mixed, Mixed]
# 1742                [Short, Mixed, Mixed, Mixed, <NA>, <NA>]
# 1853              [Short, Mixed, Mixed, Mixed, Mixed, Mixed]
# 1860              [Mixed, Mixed, Mixed, Mixed, Mixed, Mixed]
# ...
# 1742                    [Normal, Wide, Normal, Normal, <NA>, <NA>]
# 1853              [Normal, Normal, Normal, Normal, Normal, Normal]
# 1860              [Normal, Normal, Normal, Normal, Normal, Normal]
# 1861                [Narrow, Wide, Normal, Normal, Normal, Normal]
# 1867              [Normal, Normal, Normal, Normal, Normal, Normal]
# 100879              [Normal, Normal, Normal, Normal, Normal, <NA>]
# 110832                    [Wide, Wide, Wide, Normal, Normal, <NA>]
#
#                  DTWC-TEMPORADA 09/10 DTWC-TEMPORADA 10/11  \
# team_fifa_api_id
# 240                            Normal               Normal
# 241                              Wide                 Wide
# 242                            Normal                 Wide
# 243                            Normal               Normal
# 244                            Normal               Normal
# 260                            Normal                 Wide
# 448                            Normal               Normal
# 449                            Normal               Normal
# 450                            Normal               Normal
# 452                            Normal               Normal
# 453                            Normal               Normal
# 456                            Normal               Normal
# 457                            Normal               Normal
# 459                            Normal               Normal
# 461                            Normal               Normal
# 462                            Narrow               Normal
# 467                            Normal               Normal
# 468                            Normal               Normal
# 472                            Normal                 Wide
# 477                            Normal               Normal
# 479                            Normal                 Wide
# 480                            Normal                 Wide
# 481                            Normal                 Wide
# 483                              Wide               Normal
# 571                            Normal               Normal
# 573                            Normal               Normal
# 1742                           Normal                 Wide
# 1853                           Normal               Normal
# 1860                           Normal               Normal
# 1861                           Narrow                 Wide
# 1867                           Normal               Normal
# 100879                         Normal               Normal
# 110832                           Wide                 Wide
#
#                  DTWC-TEMPORADA 11/12 DTWC-TEMPORADA 12/13  \
# team_fifa_api_id
# 240                            Normal               Normal
# 241                            Normal               Normal
# 242                            Normal               Normal
# 243                              Wide               Normal
# 244                            Normal               Normal
# 260                            Normal                 Wide
# 448                              Wide                 Wide
# 449                            Normal               Normal
# 450                              Wide                 Wide
# 452                            Normal               Normal
# 453                            Normal               Normal
# 456                              Wide                 Wide
# 457                              Wide                 Wide
# 459                            Normal               Normal
# 461                            Normal               Normal
# 462                            Normal               Normal
# 467                              <NA>                 <NA>
# 468                            Normal               Normal
# 472                            Normal               Normal
# 477                            Normal               Normal
# 479                              Wide                 Wide
# 480                            Normal               Normal
# 481                            Normal               Normal
# 483                            Normal               Normal
# 571                            Normal               Normal
# 573                            Normal               Normal
# 1742                           Normal               Normal
# 1853                           Normal               Normal
# 1860                           Normal               Normal
# 1861                           Normal               Normal
# 1867                           Normal               Normal
# 100879                         Normal               Normal
# 110832                           Wide               Normal
#
#                  DTWC-TEMPORADA 13/14 DTWC-TEMPORADA 14/15  \
# team_fifa_api_id
# 240                            Normal               Normal
# 241                            Normal               Normal
# 242                            Normal               Normal
# 243                            Normal               Normal
# 244                            Normal               Normal
# 260                              <NA>                 <NA>
# 448                            Normal               Normal
# 449                            Normal               Normal
# 450                            Normal               Normal
# 452                            Normal               Normal
# 453                            Normal               Normal
# 456                            Normal                 <NA>
# 457                            Normal               Normal
# 459                            Normal               Normal
# 461                            Normal               Normal
# 462                            Normal               Normal
# 467                              <NA>                 <NA>
# 468                            Normal               Normal
# 472                            Normal               Normal
# 477                            Normal               Normal
# 479                            Normal                 Wide
# 480                            Normal               Normal
# 481                            Normal               Normal
# 483                            Normal               Normal
# 571                            Normal               Normal
# 573                            Normal               Normal
# 1742                             <NA>                 <NA>
# 1853                           Normal               Normal
# 1860                           Normal               Normal
# 1861                           Normal               Normal
# 1867                           Normal               Normal
# 100879                         Normal                 <NA>
# 110832                         Normal                 <NA>
#
#                                            defenceDefenderLineClass  \
# team_fifa_api_id
# 240               [Offside Trap, Cover, Cover, Cover, Cover, Cover]
# 241               [Offside Trap, Cover, Cover, Cover, Cover, Cover]
# 242               [Offside Trap, Cover, Cover, Cover, Cover, Off...
# 243               [Offside Trap, Cover, Cover, Cover, Cover, Cover]
# 244               [Offside Trap, Cover, Cover, Cover, Cover, Cover]
# 260                        [Cover, Cover, Cover, Cover, <NA>, <NA>]
# 448                      [Cover, Cover, Cover, Cover, Cover, Cover]
# 449               [Offside Trap, Cover, Cover, Cover, Cover, Cover]
# 450               [Offside Trap, Cover, Cover, Cover, Cover, Cover]
# 452                      [Cover, Cover, Cover, Cover, Cover, Cover]
# 453               [Offside Trap, Cover, Cover, Cover, Cover, Cover]
# 456                       [Cover, Cover, Cover, Cover, Cover, <NA>]
# 457               [Offside Trap, Cover, Cover, Cover, Cover, Cover]
# 459                      [Cover, Cover, Cover, Cover, Cover, Cover]
# 461               [Offside Trap, Cover, Cover, Cover, Cover, Cover]
# 462                      [Cover, Cover, Cover, Cover, Cover, Cover]
# 467                          [Cover, Cover, <NA>, <NA>, <NA>, <NA>]
# 468                      [Cover, Cover, Cover, Cover, Cover, Cover]
# 472               [Offside Trap, Cover, Cover, Cover, Cover, Cover]
# 477               [Offside Trap, Cover, Cover, Cover, Cover, Cover]
# 479                      [Cover, Cover, Cover, Cover, Cover, Cover]
# 480               [Offside Trap, Cover, Cover, Cover, Cover, Cover]
# 481               [Offside Trap, Cover, Cover, Cover, Cover, Cover]
# 483               [Offside Trap, Cover, Cover, Cover, Cover, Cover]
# 571                      [Cover, Cover, Cover, Cover, Cover, Cover]
# 573               [Cover, Cover, Cover, Cover, Cover, Offside Trap]
# 1742                       [Cover, Cover, Cover, Cover, <NA>, <NA>]
# 1853                     [Cover, Cover, Cover, Cover, Cover, Cover]
# 1860              [Offside Trap, Cover, Cover, Cover, Cover, Cover]
# 1861                     [Cover, Cover, Cover, Cover, Cover, Cover]
# 1867                     [Cover, Cover, Cover, Cover, Cover, Cover]
# 100879                    [Cover, Cover, Cover, Cover, Cover, <NA>]
# 110832                    [Cover, Cover, Cover, Cover, Cover, <NA>]
#
#                  DDLC-TEMPORADA 09/10 DDLC-TEMPORADA 10/11  \
# team_fifa_api_id
# 240                      Offside Trap                Cover
# 241                      Offside Trap                Cover
# 242                      Offside Trap                Cover
# 243                      Offside Trap                Cover
# 244                      Offside Trap                Cover
# 260                             Cover                Cover
# 448                             Cover                Cover
# 449                      Offside Trap                Cover
# 450                      Offside Trap                Cover
# 452                             Cover                Cover
# 453                      Offside Trap                Cover
# 456                             Cover                Cover
# 457                      Offside Trap                Cover
# 459                             Cover                Cover
# 461                      Offside Trap                Cover
# 462                             Cover                Cover
# 467                             Cover                Cover
# 468                             Cover                Cover
# 472                      Offside Trap                Cover
# 477                      Offside Trap                Cover
# 479                             Cover                Cover
# 480                      Offside Trap                Cover
# 481                      Offside Trap                Cover
# 483                      Offside Trap                Cover
# 571                             Cover                Cover
# 573                             Cover                Cover
# 1742                            Cover                Cover
# 1853                            Cover                Cover
# 1860                     Offside Trap                Cover
# 1861                            Cover                Cover
# 1867                            Cover                Cover
# 100879                          Cover                Cover
# 110832                          Cover                Cover
#
#                  DDLC-TEMPORADA 11/12 DDLC-TEMPORADA 12/13  \
# team_fifa_api_id
# 240                             Cover                Cover
# 241                             Cover                Cover
# 242                             Cover                Cover
# 243                             Cover                Cover
# 244                             Cover                Cover
# 260                             Cover                Cover
# 448                             Cover                Cover
# 449                             Cover                Cover
# 450                             Cover                Cover
# 452                             Cover                Cover
# 453                             Cover                Cover
# 456                             Cover                Cover
# 457                             Cover                Cover
# 459                             Cover                Cover
# 461                             Cover                Cover
# 462                             Cover                Cover
# 467                              <NA>                 <NA>
# 468                             Cover                Cover
# 472                             Cover                Cover
# 477                             Cover                Cover
# 479                             Cover                Cover
# 480                             Cover                Cover
# 481                             Cover                Cover
# 483                             Cover                Cover
# 571                             Cover                Cover
# 573                             Cover                Cover
# 1742                            Cover                Cover
# 1853                            Cover                Cover
# 1860                            Cover                Cover
# 1861                            Cover                Cover
# 1867                            Cover                Cover
# 100879                          Cover                Cover
# 110832                          Cover                Cover
#
#                  DDLC-TEMPORADA 13/14 DDLC-TEMPORADA 14/15
# team_fifa_api_id
# 240                             Cover                Cover
# 241                             Cover                Cover
# 242                             Cover         Offside Trap
# 243                             Cover                Cover
# 244                             Cover                Cover
# 260                              <NA>                 <NA>
# 448                             Cover                Cover
# 449                             Cover                Cover
# 450                             Cover                Cover
# 452                             Cover                Cover
# 453                             Cover                Cover
# 456                             Cover                 <NA>
# 457                             Cover                Cover
# 459                             Cover                Cover
# 461                             Cover                Cover
# 462                             Cover                Cover
# 467                              <NA>                 <NA>
# 468                             Cover                Cover
# 472                             Cover                Cover
# 477                             Cover                Cover
# 479                             Cover                Cover
# 480                             Cover                Cover
# 481                             Cover                Cover
# 483                             Cover                Cover
# 571                             Cover                Cover
# 573                             Cover         Offside Trap
# 1742                             <NA>                 <NA>
# 1853                            Cover                Cover
# 1860                            Cover                Cover
# 1861                            Cover                Cover
# 1867                            Cover                Cover
# 100879                          Cover                 <NA>
# 110832                          Cover                 <NA>

# %% [markdown]
# ## empezamos con los gráficos

# %% [markdown]
# ### scatter de prueba

# %%
#https://datacarpentry.github.io/python-ecology-lesson-es/08-putting-it-all-together.html
#https://matplotlib.org/2.0.2/users/screenshots.html
#matplotlib inline
plt.figure(figsize=(50, 25))
BUPS1 = df_f.plot("team_long_name", "BUPS-TEMPORADA 09/10", kind="scatter")
plt.xticks(rotation=90)
plt.margins(x=0.05)

# %% [markdown]
# ## gráfico de modelo

# %% [markdown]
# ### gráfico para todos los equipos

# %%
# ATENCIÓN CAMBIAR EL _BUPS PARA SU HOMOLOGO EN CADA DF!!!
df_bups = df_f[['team_long_name','BUPS-TEMPORADA 09/10',	'BUPS-TEMPORADA 10/11',	'BUPS-TEMPORADA 11/12',	'BUPS-TEMPORADA 12/13',	'BUPS-TEMPORADA 13/14',	'BUPS-TEMPORADA 14/15']]


# Suponiendo que df_f tiene equipos como filas y años como columnas
# Convertir el DataFrame a formato largo
df_bups2 = df_bups.melt(id_vars=["team_long_name"], var_name="Temporada", value_name="Valor") #["team_long_name"]

# Crear el gráfico de líneas
plt.figure(figsize=(50, 25))
bups = sns.lineplot(data=df_bups2, x="Temporada", y="Valor", hue="team_long_name", marker="o")

# Personalizar gráfico
plt.xlabel("Temporada",fontsize=64,labelpad = 50)
plt.ylabel("Build Up Play Speed",fontsize=64,labelpad = 30)
#Toquetear el eje y
bups.invert_yaxis()
# Definir rango del eje Y
plt.ylim(20, 80)

# Número de divisiones deseado
num_divisiones = 6  

# Generar los valores de las marcas (ticks)
yticks = np.linspace(20, 80, num_divisiones)  

# Aplicar las marcas al eje Y
plt.yticks(yticks)
plt.title(" Evolución del Build Up Play Speed por Temporadas",fontsize=74)
plt.legend(title="Equipos",fontsize=25,title_fontsize=54, loc="center left", bbox_to_anchor=(-0.24,0.5),borderaxespad=0.)
plt.xticks(fontsize=34,rotation=70,ha = 'right',rotation_mode='anchor') # Rotar etiquetas si hay muchos años
plt.yticks(fontsize=44,rotation=0)
plt.subplots_adjust(bottom=0.15)
#plt.margins(x=0.4)
#plt.subplots_adjust(left=0.05, right=0.75)
plt.grid(True)

# %% [markdown]
# ### gráfico para un solo equipo

# %%
df_bups = df_f[['team_long_name','BUPS-TEMPORADA 09/10',	'BUPS-TEMPORADA 10/11',	'BUPS-TEMPORADA 11/12',	'BUPS-TEMPORADA 12/13',	'BUPS-TEMPORADA 13/14',	'BUPS-TEMPORADA 14/15']]
# Escoger de que equipo hacer el gráfico
equipo_especifico = "FC Barcelona"
df_bups = df_f[['team_long_name', 'BUPS-TEMPORADA 09/10', 'BUPS-TEMPORADA 10/11', 'BUPS-TEMPORADA 11/12',
                 'BUPS-TEMPORADA 12/13', 'BUPS-TEMPORADA 13/14', 'BUPS-TEMPORADA 14/15']]

df_bups = df_bups[df_bups["team_long_name"] == equipo_especifico]  # Filtra solo un equipo

# Suponiendo que df_f tiene equipos como filas y años como columnas
# Convertir el DataFrame a formato largo
df_bups2 = df_bups.melt(id_vars=["team_long_name"], var_name="Temporada", value_name="Valor") #["team_long_name"]

# Crear el gráfico de líneas
plt.figure(figsize=(24, 12))
bups = sns.lineplot(data=df_bups2, x="Temporada", y="Valor", marker="o")

# Personalizar gráfico
plt.xlabel("Temporada",fontsize=32,labelpad = 25)
plt.ylabel("Build Up Play Speed",fontsize=32,labelpad = 15)

# ESTO SOLO PARA LOS GRÁFICOS NUMÉRICOS, PARA LOS DE PALABRAS ELIMINAR TODO MENOS EL INVERT
#Toquetear el eje y
#bups.invert_yaxis()
# Definir rango del eje Y
plt.ylim(20, 80)

# Número de divisiones deseado
num_divisiones = 6  

# Generar los valores de las marcas (ticks)
yticks = np.linspace(20, 80, num_divisiones)  

# Aplicar las marcas al eje Y
plt.yticks(yticks)

plt.title(" Evolución del Build Up Play Speed por Temporada - FC Barcelona",fontsize=32)
# plt.legend(title="Equipos",fontsize=25,title_fontsize=54, loc="center left", bbox_to_anchor=(-0.24,0.5),borderaxespad=0.)
plt.xticks(fontsize=17,rotation=70,ha = 'right',rotation_mode='anchor') # Rotar etiquetas si hay muchos años
plt.yticks(fontsize=22,rotation=0)
plt.subplots_adjust(bottom=0.15)
#plt.margins(x=0.4)
#plt.subplots_adjust(left=0.05, right=0.75)
plt.grid(True)

# %% [markdown]
# ## GRÁFICOS DEL FC BARCELONA

# %% [markdown]
# ### GRÁFICO BUPS

# %%
# Escoger de que equipo hacer el gráfico
equipo_especifico = "FC Barcelona"
df_bups = df_f[['team_long_name', 'BUPS-TEMPORADA 09/10', 'BUPS-TEMPORADA 10/11', 'BUPS-TEMPORADA 11/12',
                 'BUPS-TEMPORADA 12/13', 'BUPS-TEMPORADA 13/14', 'BUPS-TEMPORADA 14/15']]

df_bups = df_bups[df_bups["team_long_name"] == equipo_especifico]  # Filtra solo un equipo

# Suponiendo que df_f tiene equipos como filas y años como columnas
# Convertir el DataFrame a formato largo
df_bups2 = df_bups.melt(id_vars=["team_long_name"], var_name="Temporada", value_name="Valor") #["team_long_name"]

# Crear el gráfico de líneas
plt.figure(figsize=(24, 12))
bups = sns.lineplot(data=df_bups2, x="Temporada", y="Valor", marker="o")

# Personalizar gráfico
plt.xlabel("Temporada",fontsize=32,labelpad = 25)
plt.ylabel("Build Up Play Speed",fontsize=32,labelpad = 15)

# ESTO SOLO PARA LOS GRÁFICOS NUMÉRICOS, PARA LOS DE PALABRAS ELIMINAR TODO MENOS EL INVERT
#Toquetear el eje y
#bupsc.invert_yaxis()
# Definir rango del eje Y
plt.ylim(20, 80)

# Número de divisiones deseado
num_divisiones = 6  

# Generar los valores de las marcas (ticks)
yticks = np.linspace(20, 80, num_divisiones)  

# Aplicar las marcas al eje Y
plt.yticks(yticks)

plt.title(" Evolución del Build Up Play Speed por Temporada - FC Barcelona",fontsize=32)
# plt.legend(title="Equipos",fontsize=25,title_fontsize=54, loc="center left", bbox_to_anchor=(-0.24,0.5),borderaxespad=0.)

plt.xticks(fontsize=17,rotation=70,ha = 'right',rotation_mode='anchor') # Rotar etiquetas si hay muchos años
nombres_personalizados = ["TEMPORADA 09/10", "TEMPORADA 10/11", "TEMPORADA 11/12", "TEMPORADA 12/13", "TEMPORADA 13/14", "TEMPORADA 14/15"]
plt.xticks(ticks=range(len(nombres_personalizados)), labels=nombres_personalizados)

plt.yticks(fontsize=22,rotation=0)

plt.subplots_adjust(bottom=0.15)
#plt.margins(x=0.4)
#plt.subplots_adjust(left=0.05, right=0.75)
plt.grid(True)

# %% [markdown]
# ### GRÁFICO BUPP

# %%
df_bupp = df_f[['team_long_name','BUPP-TEMPORADA 09/10',	'BUPP-TEMPORADA 10/11',	'BUPP-TEMPORADA 11/12',	'BUPP-TEMPORADA 12/13',	'BUPP-TEMPORADA 13/14',	'BUPP-TEMPORADA 14/15']]
# Escoger de que equipo hacer el gráfico
equipo_especifico = "FC Barcelona"
df_bupp = df_f[['team_long_name', 'BUPP-TEMPORADA 09/10', 'BUPP-TEMPORADA 10/11', 'BUPP-TEMPORADA 11/12',
                 'BUPP-TEMPORADA 12/13', 'BUPP-TEMPORADA 13/14', 'BUPP-TEMPORADA 14/15']]

df_bupp= df_bupp[df_bupp["team_long_name"] == equipo_especifico]  # Filtra solo un equipo

# Suponiendo que df_f tiene equipos como filas y años como columnas
# Convertir el DataFrame a formato largo
df_bupp2 = df_bupp.melt(id_vars=["team_long_name"], var_name="Temporada", value_name="Valor") #["team_long_name"]

# Crear el gráfico de líneas
plt.figure(figsize=(24, 12))
bupp = sns.lineplot(data=df_bupp2, x="Temporada", y="Valor", marker="o")

# Personalizar gráfico
plt.xlabel("Temporada",fontsize=32,labelpad = 25)
plt.ylabel("Build Up Play Passing",fontsize=32,labelpad = 15)

# ESTO SOLO PARA LOS GRÁFICOS NUMÉRICOS, PARA LOS DE PALABRAS ELIMINAR TODO MENOS EL INVERT
#Toquetear el eje y
#bupp.invert_yaxis()
# Definir rango del eje Y
plt.ylim(20, 80)

# Número de divisiones deseado
num_divisiones = 6  

# Generar los valores de las marcas (ticks)
yticks = np.linspace(20, 80, num_divisiones)  

# Aplicar las marcas al eje Y
plt.yticks(yticks)

plt.title(" Evolución del Build Up Play Passing por Temporada - FC Barcelona",fontsize=32)
# plt.legend(title="Equipos",fontsize=25,title_fontsize=54, loc="center left", bbox_to_anchor=(-0.24,0.5),borderaxespad=0.)

plt.xticks(fontsize=17,rotation=70,ha = 'right',rotation_mode='anchor') # Rotar etiquetas si hay muchos años
nombres_personalizados = ["TEMPORADA 09/10", "TEMPORADA 10/11", "TEMPORADA 11/12", "TEMPORADA 12/13", "TEMPORADA 13/14", "TEMPORADA 14/15"]
plt.xticks(ticks=range(len(nombres_personalizados)), labels=nombres_personalizados)

plt.yticks(fontsize=22,rotation=0)
plt.subplots_adjust(bottom=0.15)
#plt.margins(x=0.4)
#plt.subplots_adjust(left=0.05, right=0.75)
plt.grid(True)

# %% [markdown]
# ### GRÁFICO CCP

# %%
df_ccp = df_f[['team_long_name','CCP-TEMPORADA 09/10',	'CCP-TEMPORADA 10/11',	'CCP-TEMPORADA 11/12',	'CCP-TEMPORADA 12/13',	'CCP-TEMPORADA 13/14',	'CCP-TEMPORADA 14/15']]
# Escoger de que equipo hacer el gráfico
equipo_especifico = "FC Barcelona"
df_ccp = df_f[['team_long_name', 'CCP-TEMPORADA 09/10', 'CCP-TEMPORADA 10/11', 'CCP-TEMPORADA 11/12',
                 'CCP-TEMPORADA 12/13', 'CCP-TEMPORADA 13/14', 'CCP-TEMPORADA 14/15']]

df_ccp= df_ccp[df_ccp["team_long_name"] == equipo_especifico]  # Filtra solo un equipo

# Suponiendo que df_f tiene equipos como filas y años como columnas
# Convertir el DataFrame a formato largo
df_ccp2 = df_ccp.melt(id_vars=["team_long_name"], var_name="Temporada", value_name="Valor") #["team_long_name"]

# Crear el gráfico de líneas
plt.figure(figsize=(24, 12))
ccp = sns.lineplot(data=df_ccp2, x="Temporada", y="Valor", marker="o")

# Personalizar gráfico
plt.xlabel("Temporada",fontsize=32,labelpad = 25)
plt.ylabel("Chance Creation Passing",fontsize=32,labelpad = 15)

# ESTO SOLO PARA LOS GRÁFICOS NUMÉRICOS, PARA LOS DE PALABRAS ELIMINAR TODO MENOS EL INVERT
#Toquetear el eje y
#ccp.invert_yaxis()
# Definir rango del eje Y
plt.ylim(20, 80)

# Número de divisiones deseado
num_divisiones = 6  

# Generar los valores de las marcas (ticks)
yticks = np.linspace(20, 80, num_divisiones)  

# Aplicar las marcas al eje Y
plt.yticks(yticks)

plt.title(" Evolución del Chance Creation Passing por Temporada - FC Barcelona",fontsize=32)
# plt.legend(title="Equipos",fontsize=25,title_fontsize=54, loc="center left", bbox_to_anchor=(-0.24,0.5),borderaxespad=0.)

plt.xticks(fontsize=17,rotation=70,ha = 'right',rotation_mode='anchor') # Rotar etiquetas si hay muchos años
nombres_personalizados = ["TEMPORADA 09/10", "TEMPORADA 10/11", "TEMPORADA 11/12", "TEMPORADA 12/13", "TEMPORADA 13/14", "TEMPORADA 14/15"]
plt.xticks(ticks=range(len(nombres_personalizados)), labels=nombres_personalizados)

plt.yticks(fontsize=22,rotation=0)
plt.subplots_adjust(bottom=0.15)
#plt.margins(x=0.4)
#plt.subplots_adjust(left=0.05, right=0.75)
plt.grid(True)

# %% [markdown]
# ### GRÁFICO CCC

# %%
df_ccc = df_f[['team_long_name','CCC-TEMPORADA 09/10',	'CCC-TEMPORADA 10/11',	'CCC-TEMPORADA 11/12',	'CCC-TEMPORADA 12/13',	'CCC-TEMPORADA 13/14',	'CCC-TEMPORADA 14/15']]
# Escoger de que equipo hacer el gráfico
equipo_especifico = "FC Barcelona"
df_ccc = df_f[['team_long_name', 'CCC-TEMPORADA 09/10', 'CCC-TEMPORADA 10/11', 'CCC-TEMPORADA 11/12',
                 'CCC-TEMPORADA 12/13', 'CCC-TEMPORADA 13/14', 'CCC-TEMPORADA 14/15']]

df_ccc= df_ccc[df_ccc["team_long_name"] == equipo_especifico]  # Filtra solo un equipo

# Suponiendo que df_f tiene equipos como filas y años como columnas
# Convertir el DataFrame a formato largo
df_ccc2 = df_ccc.melt(id_vars=["team_long_name"], var_name="Temporada", value_name="Valor") #["team_long_name"]

# Crear el gráfico de líneas
plt.figure(figsize=(24, 12))
ccc = sns.lineplot(data=df_ccc2, x="Temporada", y="Valor", marker="o")

# Personalizar gráfico
plt.xlabel("Temporada",fontsize=32,labelpad = 25)
plt.ylabel("Chance Creation Crossing",fontsize=32,labelpad = 15)

# ESTO SOLO PARA LOS GRÁFICOS NUMÉRICOS, PARA LOS DE PALABRAS ELIMINAR TODO MENOS EL INVERT
#Toquetear el eje y
#ccc.invert_yaxis()
# Definir rango del eje Y
plt.ylim(20, 80)

# Número de divisiones deseado
num_divisiones = 6  

# Generar los valores de las marcas (ticks)
yticks = np.linspace(20, 80, num_divisiones)  

# Aplicar las marcas al eje Y
plt.yticks(yticks)

plt.title(" Evolución del Chance Creation Crossing por Temporada - FC Barcelona",fontsize=32)
# plt.legend(title="Equipos",fontsize=25,title_fontsize=54, loc="center left", bbox_to_anchor=(-0.24,0.5),borderaxespad=0.)

plt.xticks(fontsize=17,rotation=70,ha = 'right',rotation_mode='anchor') # Rotar etiquetas si hay muchos años
nombres_personalizados = ["TEMPORADA 09/10", "TEMPORADA 10/11", "TEMPORADA 11/12", "TEMPORADA 12/13", "TEMPORADA 13/14", "TEMPORADA 14/15"]
plt.xticks(ticks=range(len(nombres_personalizados)), labels=nombres_personalizados)

plt.yticks(fontsize=22,rotation=0)
plt.subplots_adjust(bottom=0.15)
#plt.margins(x=0.4)
#plt.subplots_adjust(left=0.05, right=0.75)
plt.grid(True)

# %% [markdown]
# ### GRÁFICO CCS

# %%
df_ccs = df_f[['team_long_name','CCS-TEMPORADA 09/10',	'CCS-TEMPORADA 10/11',	'CCS-TEMPORADA 11/12',	'CCS-TEMPORADA 12/13',	'CCS-TEMPORADA 13/14',	'CCS-TEMPORADA 14/15']]

# Escoger de que equipo hacer el gráfico
equipo_especifico = "FC Barcelona"
df_ccs = df_f[['team_long_name', 'CCS-TEMPORADA 09/10', 'CCS-TEMPORADA 10/11', 'CCS-TEMPORADA 11/12',
                 'CCS-TEMPORADA 12/13', 'CCS-TEMPORADA 13/14', 'CCS-TEMPORADA 14/15']]

df_ccs= df_ccs[df_ccs["team_long_name"] == equipo_especifico]  # Filtra solo un equipo

# Suponiendo que df_f tiene equipos como filas y años como columnas
# Convertir el DataFrame a formato largo
df_ccs2 = df_ccs.melt(id_vars=["team_long_name"], var_name="Temporada", value_name="Valor") #["team_long_name"]

# Crear el gráfico de líneas
plt.figure(figsize=(24, 12))
ccs = sns.lineplot(data=df_ccs2, x="Temporada", y="Valor", marker="o")

# Personalizar gráfico
plt.xlabel("Temporada",fontsize=32,labelpad = 25)
plt.ylabel("Chance Creation Shooting",fontsize=32,labelpad = 15)

# ESTO SOLO PARA LOS GRÁFICOS NUMÉRICOS, PARA LOS DE PALABRAS ELIMINAR TODO MENOS EL INVERT
#Toquetear el eje y
#ccs.invert_yaxis()
# Definir rango del eje Y
plt.ylim(20, 80)

# Número de divisiones deseado
num_divisiones = 6  

# Generar los valores de las marcas (ticks)
yticks = np.linspace(20, 80, num_divisiones)  

# Aplicar las marcas al eje Y
plt.yticks(yticks)

plt.title(" Evolución del Chance Creation Shooting por Temporada - FC Barcelona",fontsize=32)
# plt.legend(title="Equipos",fontsize=25,title_fontsize=54, loc="center left", bbox_to_anchor=(-0.24,0.5),borderaxespad=0.)

plt.xticks(fontsize=17,rotation=70,ha = 'right',rotation_mode='anchor') # Rotar etiquetas si hay muchos años
nombres_personalizados = ["TEMPORADA 09/10", "TEMPORADA 10/11", "TEMPORADA 11/12", "TEMPORADA 12/13", "TEMPORADA 13/14", "TEMPORADA 14/15"]
plt.xticks(ticks=range(len(nombres_personalizados)), labels=nombres_personalizados)

plt.yticks(fontsize=22,rotation=0)
plt.subplots_adjust(bottom=0.15)
#plt.margins(x=0.4)
#plt.subplots_adjust(left=0.05, right=0.75)
plt.grid(True)

# %% [markdown]
# ### GRÁFICO DP

# %%
df_dp = df_f[['team_long_name','DP-TEMPORADA 09/10',	'DP-TEMPORADA 10/11',	'DP-TEMPORADA 11/12',	'DP-TEMPORADA 12/13',	'DP-TEMPORADA 13/14',	'DP-TEMPORADA 14/15']]
# Escoger de que equipo hacer el gráfico
equipo_especifico = "FC Barcelona"
df_dp = df_f[['team_long_name', 'DP-TEMPORADA 09/10', 'DP-TEMPORADA 10/11', 'DP-TEMPORADA 11/12',
                 'DP-TEMPORADA 12/13', 'DP-TEMPORADA 13/14', 'DP-TEMPORADA 14/15']]

df_dp= df_dp[df_dp["team_long_name"] == equipo_especifico]  # Filtra solo un equipo

# Suponiendo que df_f tiene equipos como filas y años como columnas
# Convertir el DataFrame a formato largo
df_dp2 = df_dp.melt(id_vars=["team_long_name"], var_name="Temporada", value_name="Valor") #["team_long_name"]

# Crear el gráfico de líneas
plt.figure(figsize=(24, 12))
dp = sns.lineplot(data=df_dp2, x="Temporada", y="Valor", marker="o")

# Personalizar gráfico
plt.xlabel("Temporada",fontsize=32,labelpad = 25)
plt.ylabel("Defence Pressure",fontsize=32,labelpad = 15)

# ESTO SOLO PARA LOS GRÁFICOS NUMÉRICOS, PARA LOS DE PALABRAS ELIMINAR TODO MENOS EL INVERT
#Toquetear el eje y
#dp.invert_yaxis()
# Definir rango del eje Y
plt.ylim(20, 80)

# Número de divisiones deseado
num_divisiones = 6  

# Generar los valores de las marcas (ticks)
yticks = np.linspace(20, 80, num_divisiones)  

# Aplicar las marcas al eje Y
plt.yticks(yticks)

plt.title(" Evolución del Defence Pressure por Temporada - FC Barcelona",fontsize=32)
# plt.legend(title="Equipos",fontsize=25,title_fontsize=54, loc="center left", bbox_to_anchor=(-0.24,0.5),borderaxespad=0.)

plt.xticks(fontsize=17,rotation=70,ha = 'right',rotation_mode='anchor') # Rotar etiquetas si hay muchos años
nombres_personalizados = ["TEMPORADA 09/10", "TEMPORADA 10/11", "TEMPORADA 11/12", "TEMPORADA 12/13", "TEMPORADA 13/14", "TEMPORADA 14/15"]
plt.xticks(ticks=range(len(nombres_personalizados)), labels=nombres_personalizados)

plt.yticks(fontsize=22,rotation=0)
plt.subplots_adjust(bottom=0.15)
#plt.margins(x=0.4)
#plt.subplots_adjust(left=0.05, right=0.75)
plt.grid(True)

# %% [markdown]
# ### GRÁFICO DA

# %%
df_da = df_f[['team_long_name','DA-TEMPORADA 09/10',	'DA-TEMPORADA 10/11',	'DA-TEMPORADA 11/12',	'DA-TEMPORADA 12/13',	'DA-TEMPORADA 13/14',	'DA-TEMPORADA 14/15']]

# Escoger de que equipo hacer el gráfico
equipo_especifico = "FC Barcelona"
df_da = df_f[['team_long_name', 'DA-TEMPORADA 09/10', 'DA-TEMPORADA 10/11', 'DA-TEMPORADA 11/12',
                 'DA-TEMPORADA 12/13', 'DA-TEMPORADA 13/14', 'DA-TEMPORADA 14/15']]

df_da= df_da[df_da["team_long_name"] == equipo_especifico]  # Filtra solo un equipo

# Suponiendo que df_f tiene equipos como filas y años como columnas
# Convertir el DataFrame a formato largo
df_da2 = df_da.melt(id_vars=["team_long_name"], var_name="Temporada", value_name="Valor") #["team_long_name"]

# Crear el gráfico de líneas
plt.figure(figsize=(24, 12))
da = sns.lineplot(data=df_da2, x="Temporada", y="Valor", marker="o")

# Personalizar gráfico
plt.xlabel("Temporada",fontsize=32,labelpad = 25)
plt.ylabel("Defence Agression",fontsize=32,labelpad = 15)

# ESTO SOLO PARA LOS GRÁFICOS NUMÉRICOS, PARA LOS DE PALABRAS ELIMINAR TODO MENOS EL INVERT
#Toquetear el eje y
#da.invert_yaxis()
# Definir rango del eje Y
plt.ylim(20, 80)

# Número de divisiones deseado
num_divisiones = 6  

# Generar los valores de las marcas (ticks)
yticks = np.linspace(20, 80, num_divisiones)  

# Aplicar las marcas al eje Y
plt.yticks(yticks)

plt.title(" Evolución del Defence Agression por Temporada - FC Barcelona",fontsize=32)
# plt.legend(title="Equipos",fontsize=25,title_fontsize=54, loc="center left", bbox_to_anchor=(-0.24,0.5),borderaxespad=0.)

plt.xticks(fontsize=17,rotation=70,ha = 'right',rotation_mode='anchor') # Rotar etiquetas si hay muchos años
nombres_personalizados = ["TEMPORADA 09/10", "TEMPORADA 10/11", "TEMPORADA 11/12", "TEMPORADA 12/13", "TEMPORADA 13/14", "TEMPORADA 14/15"]
plt.xticks(ticks=range(len(nombres_personalizados)), labels=nombres_personalizados)

plt.yticks(fontsize=22,rotation=0)
plt.subplots_adjust(bottom=0.15)
#plt.margins(x=0.4)
#plt.subplots_adjust(left=0.05, right=0.75)
plt.grid(True)

# %% [markdown]
# ### GRÁFICO DTW

# %%
df_dtw = df_f[['team_long_name','DTW-TEMPORADA 09/10',	'DTW-TEMPORADA 10/11',	'DTW-TEMPORADA 11/12',	'DTW-TEMPORADA 12/13',	'DTW-TEMPORADA 13/14',	'DTW-TEMPORADA 14/15']]

# Escoger de que equipo hacer el gráfico
equipo_especifico = "FC Barcelona"
df_dtw = df_f[['team_long_name', 'DTW-TEMPORADA 09/10', 'DTW-TEMPORADA 10/11', 'DTW-TEMPORADA 11/12',
                 'DTW-TEMPORADA 12/13', 'DTW-TEMPORADA 13/14', 'DTW-TEMPORADA 14/15']]

df_dtw= df_dtw[df_dtw["team_long_name"] == equipo_especifico]  # Filtra solo un equipo

# Suponiendo que df_f tiene equipos como filas y años como columnas
# Convertir el DataFrame a formato largo
df_dtw2 = df_dtw.melt(id_vars=["team_long_name"], var_name="Temporada", value_name="Valor") #["team_long_name"]

# Crear el gráfico de líneas
plt.figure(figsize=(24, 12))
dtw = sns.lineplot(data=df_dtw2, x="Temporada", y="Valor", marker="o")

# Personalizar gráfico
plt.xlabel("Temporada",fontsize=32,labelpad = 25)
plt.ylabel("Defence Team Width",fontsize=32,labelpad = 15)


# ESTO SOLO PARA LOS GRÁFICOS NUMÉRICOS, PARA LOS DE PALABRAS ELIMINAR TODO MENOS EL INVERT
#Toquetear el eje y
#dtw.invert_yaxis()
# Definir rango del eje Y
plt.ylim(20, 80)

# Número de divisiones deseado
num_divisiones = 6  

# Generar los valores de las marcas (ticks)
yticks = np.linspace(20, 80, num_divisiones)  

# Aplicar las marcas al eje Y
plt.yticks(yticks)

plt.title(" Evolución del Defence Team Width por Temporada - FC Barcelona",fontsize=32)
# plt.legend(title="Equipos",fontsize=25,title_fontsize=54, loc="center left", bbox_to_anchor=(-0.24,0.5),borderaxespad=0.)

plt.xticks(fontsize=17,rotation=70,ha = 'right',rotation_mode='anchor') # Rotar etiquetas si hay muchos años
nombres_personalizados = ["TEMPORADA 09/10", "TEMPORADA 10/11", "TEMPORADA 11/12", "TEMPORADA 12/13", "TEMPORADA 13/14", "TEMPORADA 14/15"]
plt.xticks(ticks=range(len(nombres_personalizados)), labels=nombres_personalizados)

plt.yticks(fontsize=22,rotation=0)
plt.subplots_adjust(bottom=0.15)
#plt.margins(x=0.4)
#plt.subplots_adjust(left=0.05, right=0.75)
plt.grid(True)

# %% [markdown]
# ### GRÁFICO FUSIONADO DEFENSA

# %%
df_dtw = df_f[['team_long_name','DTW-TEMPORADA 09/10',	'DTW-TEMPORADA 10/11',	'DTW-TEMPORADA 11/12',	'DTW-TEMPORADA 12/13',	'DTW-TEMPORADA 13/14',	'DTW-TEMPORADA 14/15']]

# Escoger de que equipo hacer el gráfico
equipo_especifico = "FC Barcelona"
df_dtw = df_f[['team_long_name', 'DTW-TEMPORADA 09/10', 'DTW-TEMPORADA 10/11', 'DTW-TEMPORADA 11/12',
                 'DTW-TEMPORADA 12/13', 'DTW-TEMPORADA 13/14', 'DTW-TEMPORADA 14/15']]

df_dtw= df_dtw[df_dtw["team_long_name"] == equipo_especifico]  # Filtra solo un equipo

# Suponiendo que df_f tiene equipos como filas y años como columnas
# Convertir el DataFrame a formato largo
df_dtw2 = df_dtw.melt(id_vars=["team_long_name"], var_name="Temporada", value_name="Valor") #["team_long_name"]

# Crear el gráfico de líneas
plt.figure(figsize=(24, 12))
dtw = sns.lineplot(data=df_dtw2, x="Temporada", y="Valor", marker="o")
da = sns.lineplot(data=df_da2, x="Temporada", y="Valor", marker="o")
dp = sns.lineplot(data=df_dp2, x="Temporada", y="Valor", marker="o")

# Personalizar gráfico
plt.xlabel("Temporada",fontsize=32,labelpad = 25)
plt.ylabel("Defence Team Width",fontsize=32,labelpad = 15)


# ESTO SOLO PARA LOS GRÁFICOS NUMÉRICOS, PARA LOS DE PALABRAS ELIMINAR TODO MENOS EL INVERT
#Toquetear el eje y
#dtw.invert_yaxis()
# Definir rango del eje Y
plt.ylim(20, 80)

# Número de divisiones deseado
num_divisiones = 6  

# Generar los valores de las marcas (ticks)
yticks = np.linspace(20, 80, num_divisiones)  

# Aplicar las marcas al eje Y
plt.yticks(yticks)

plt.title(" Evolución del Defence Team Width por Temporada - FC Barcelona",fontsize=32)
# plt.legend(title="Equipos",fontsize=25,title_fontsize=54, loc="center left", bbox_to_anchor=(-0.24,0.5),borderaxespad=0.)

plt.xticks(fontsize=17,rotation=70,ha = 'right',rotation_mode='anchor') # Rotar etiquetas si hay muchos años
nombres_personalizados = ["TEMPORADA 09/10", "TEMPORADA 10/11", "TEMPORADA 11/12", "TEMPORADA 12/13", "TEMPORADA 13/14", "TEMPORADA 14/15"]
plt.xticks(ticks=range(len(nombres_personalizados)), labels=nombres_personalizados)

plt.yticks(fontsize=22,rotation=0)
plt.subplots_adjust(bottom=0.15)
#plt.margins(x=0.4)
#plt.subplots_adjust(left=0.05, right=0.75)
plt.grid(True)

# %% [markdown]
# # SPARKLINES

# %% [markdown]
# ### CÓDIGO PARA CREAR TABLA DE SPARKLINES Y MODIFICARLA A GUSTO PERSONAL

# %%
CONFIG = {
    "sparkline_size": (2.0, 0.5),  # Tamaño aumentado para mejor visualización
    "line_color": "#1f77b4",
    "line_width": 2,
    "dot_color": "#ff7f0e",
    "dot_size": 30,
    "bg_color": "none",
    "font_size": "14px",
    "table_style": {
        "width": "100%",
        "header_bg": "#2C3E50",
        "header_text": "white",
        "cell_padding": "8px",
        "border": "1px solid #ddd"
    }
}
#SPARKLINES

def create_sparkline(data, years):
    try:
        fig, ax = plt.subplots(figsize=CONFIG["sparkline_size"])
        fig.patch.set_alpha(0.0)  # Fondo transparente
        
        # Filtrar datos válidos
        valid_data = [y for y in data if pd.notna(y)]
        valid_years = [years[i] for i, y in enumerate(data) if pd.notna(y)]
        
        if valid_data:
            ax.plot(valid_years, valid_data, 
                   color=CONFIG["line_color"], 
                   linewidth=CONFIG["line_width"])
            ax.scatter(valid_years, valid_data, 
                      color=CONFIG["dot_color"], 
                      s=CONFIG["dot_size"])
        
        ax.axis('off')
        plt.tight_layout()
        
        buf = BytesIO()
        plt.savefig(buf, format='png', bbox_inches='tight', dpi=120)
        plt.close(fig)
        return base64.b64encode(buf.getvalue()).decode('utf-8')
    
    except Exception as e:
        print(f"Error: {str(e)}")
        return None

#FUNCIÓN PRINCIPAL

l = df_f[['buildUpPlaySpeed', 'buildUpPlayDribbling', 'buildUpPlayPassing', 'chanceCreationPassing', 'chanceCreationCrossing', 'chanceCreationShooting', 'defencePressure', 'defenceAggression', 'defenceTeamWidth' ]]
def generate_team_report(df, team_name, years):
    try:
        team_data = df[df['team_long_name'] == team_name].iloc[0]
        metrics = [col for col in l.columns if isinstance(team_data[col], (list, np.ndarray))]
        
        def format_values(value_list):
            try:
                return ", ".join([f"{float(v):.1f}" for v in value_list if pd.notna(v)])
            except:
                return str(value_list)
        
        html = f"""
        <style>
            .compact-report {{
                width: {CONFIG["table_style"]["width"]};
                max-width: 500px;
                border-collapse: collapse;
                margin: 0 auto;
                font-family: Arial;
                table-layout: fixed;
            }}
            .compact-report th {{
                background-color: {CONFIG["table_style"]["header_bg"]};
                color: {CONFIG["table_style"]["header_text"]};
                padding: 12px;
                text-align: left;
                font-size: 16px;
                border: {CONFIG["table_style"]["border"]};
                position: sticky;
                top: 0;
            }}
            .compact-report td {{
                padding: {CONFIG["table_style"]["cell_padding"]};
                border: {CONFIG["table_style"]["border"]};
                vertical-align: left;
            }}
            .metric-column {{
                width: 60%;
                text-align: left;
                font-size: 14px;
                padding-left: 15px;
            }}
            .values-column {{
                width: 30%;
                text-align: center;
                font-family: monospace;
                font-size: 13px;
            }}
            .sparkline-column {{
                width: 40%;
                text-align: center;
            }}
            .sparkline-img {{
                max-width: 100%;
                height: auto;
                display: block;
                margin: 0 auto;
            }}
        </style>
        <table class='compact-report'>
            <thead>
                <tr>
                    <th colspan="3" style="font-size: 18px;text-align: center">{team_name.upper()}</th>
                </tr>
                <tr>
                    <th class="metric-column" style="font-size: 18px;text-align: center">METRIC</th>
                    <th class="values-column" style="font-size: 18px;text-align: center">VALUES</th>
                    <th class="sparkline-column" style="font-size: 18px;text-align: center">6 YEARS TREND</th>
                </tr>
            </thead>
            <tbody>
        """

        def format_metric_name(metric_name):
            import re
            formatted = re.sub(r'(?<=[a-z])(?=[A-Z])', ' ', metric_name)
            return formatted.title()
            
        def format_values(values):
            return ", ".join([f"{v:.1f}" if isinstance(v, (int, float)) else str(v) for v in values])
            
        for metric in metrics:
            sparkline_b64 = create_sparkline(team_data[metric], years)
            sparkline_html = f'<img class="sparkline-img" src="data:image/png;base64,{sparkline_b64}">' if sparkline_b64 else "No data"
            metric_display = format_metric_name(metric)
            values_display = format_values(team_data[metric])
            html += f"""
            <tr>
                <td class="metric-column">{metric_display}</td>
                <td class="values-column">{values_display}</td>
                <td class="sparkline-column">{sparkline_html}</td>
            </tr>
            """
        
        html += "</tbody></table>"
        return HTML(html)
    
    except Exception as e:
        return HTML(f"<p style='color:red; font-size:12px;'>Error generating report: {str(e)}</p>")

# Ejecución
YEARS = ['09/10', '10/11', '11/12', '12/13', '13/14', '14/15']
TEAM = "FC Barcelona"

report = generate_team_report(df_f, TEAM, YEARS)
display(report)
# Comando para poder guardar la imagen
with open("table.html", "w") as f:
    f.write(generate_team_report(df_f, "FC Barcelona", YEARS).data)
# Out:
#         <style>
#             .compact-report {
#                 width: 100%;
#                 max-width: 500px;
#                 border-collapse: collapse;
#                 margin: 0 auto;
#                 font-family: Arial;
#                 table-layout: fixed;
#             }
#             .compact-report th {
#                 background-color: #2C3E50;
#                 color: white;
#                 padding: 12px;
#                 text-align: left;
#                 font-size: 16px;
#                 border: 1px solid #ddd;
#                 position: sticky;
#                 top: 0;
#             }
#             .compact-report td {
#                 padding: 8px;
#                 border: 1px solid #ddd;
#                 vertical-align: left;
#             }
#             .metric-column {
#                 width: 60%;
#                 text-align: left;
#                 font-size: 14px;
#                 padding-left: 15px;
#             }
#             .values-column {
#                 width: 30%;
#                 text-align: center;
#                 font-family: monospace;
#                 font-size: 13px;
#             }
#             .sparkline-column {
#                 width: 40%;
#                 text-align: center;
#             }
#             .sparkline-img {
#                 max-width: 100%;
#                 height: auto;
#                 display: block;
#                 margin: 0 auto;
#             }
#         </style>
#         <table class='compact-report'>
#             <thead>
#                 <tr>
#                     <th colspan="3" style="font-size: 18px;text-align: center">FC BARCELONA</th>
#                 </tr>
#                 <tr>
#                     <th class="metric-column" style="font-size: 18px;text-align: center">METRIC</th>
#                     <th class="values-column" style="font-size: 18px;text-align: center">VALUES</th>
#                     <th class="sparkline-column" style="font-size: 18px;text-align: center">6 YEARS TREND</th>
#                 </tr>
#             </thead>
#             <tbody>
#
#             <tr>
#                 <td class="metric-column">Build Up Play Speed</td>
#                 <td class="values-column">42.0, 43.0, 24.0, 35.0, 35.0, 36.0</td>
#                 <td class="sparkline-column"><img class="sparkline-img" src="data:image/png;base64,..."></td>
#             </tr>
#
#             <tr>
#                 <td class="metric-column">Build Up Play Dribbling</td>
#                 <td class="values-column"><NA>, <NA>, <NA>, <NA>, 35.0, 35.0</td>
#                 <td class="sparkline-column"><img class="sparkline-img" src="data:image/png;base64,..."></td>
#             </tr>
#
#             <tr>
#                 <td class="metric-column">Build Up Play Passing</td>
#                 <td class="values-column">30.0, 34.0, 25.0, 32.0, 32.0, 51.0</td>
#                 <td class="sparkline-column"><img class="sparkline-img" src="data:image/png;base64,..."></td>
#             </tr>
#
#             <tr>
#                 <td class="metric-column">Chance Creation Passing</td>
#                 <td class="values-column">65.0, 59.0, 37.0, 37.0, 37.0, 36.0</td>
#                 <td class="sparkline-column"><img class="sparkline-img" src="data:image/png;base64,..."></td>
#             </tr>
#
#             <tr>
#                 <td class="metric-column">Chance Creation Crossing</td>
#                 <td class="values-column">40.0, 25.0, 24.0, 31.0, 31.0, 49.0</td>
#                 <td class="sparkline-column"><img class="sparkline-img" src="data:image/png;base64,..."></td>
#             </tr>
#
#             <tr>
#                 <td class="metric-column">Chance Creation Shooting</td>
#                 <td class="values-column">70.0, 68.0, 54.0, 35.0, 35.0, 56.0</td>
#                 <td class="sparkline-column"><img class="sparkline-img" src="data:image/png;base64,..."></td>
#             </tr>
#
#             <tr>
#                 <td class="metric-column">Defence Pressure</td>
#                 <td class="values-column">70.0, 67.0, 66.0, 61.0, 61.0, 61.0</td>
#                 <td class="sparkline-column"><img class="sparkline-img" src="data:image/png;base64,..."></td>
#             </tr>
#
#             <tr>
#                 <td class="metric-column">Defence Aggression</td>
#                 <td class="values-column">30.0, 43.0, 63.0, 63.0, 63.0, 65.0</td>
#                 <td class="sparkline-column"><img class="sparkline-img" src="data:image/png;base64,..."></td>
#             </tr>
#
#             <tr>
#                 <td class="metric-column">Defence Team Width</td>
#                 <td class="values-column">70.0, 68.0, 66.0, 65.0, 65.0, 65.0</td>
#                 <td class="sparkline-column"><img class="sparkline-img" src="data:image/png;base64,..."></td>
#             </tr>
#             </tbody></table>

# %%
CONFIG = {
    "sparkline_size": (2.0, 0.5),  # Tamaño aumentado para mejor visualización
    "line_color": "#1f77b4",
    "line_width": 2,
    "dot_color": "#ff7f0e",
    "dot_size": 30,
    "bg_color": "none",
    "font_size": "14px",
    "table_style": {
        "width": "100%",
        "header_bg": "#2C3E50",
        "header_text": "white",
        "cell_padding": "8px",
        "border": "1px solid #ddd"
    }
}
#SPARKLINES

def create_sparkline(data, years):
    try:
        fig, ax = plt.subplots(figsize=CONFIG["sparkline_size"])
        fig.patch.set_alpha(0.0)  # Fondo transparente
        
        # Filtrar datos válidos
        valid_data = [y for y in data if pd.notna(y)]
        valid_years = [years[i] for i, y in enumerate(data) if pd.notna(y)]
        
        if valid_data:
            ax.plot(valid_years, valid_data, 
                   color=CONFIG["line_color"], 
                   linewidth=CONFIG["line_width"])
            ax.scatter(valid_years, valid_data, 
                      color=CONFIG["dot_color"], 
                      s=CONFIG["dot_size"])
        
        ax.axis('off')
        plt.tight_layout()
        
        buf = BytesIO()
        plt.savefig(buf, format='png', bbox_inches='tight', dpi=120)
        plt.close(fig)
        return base64.b64encode(buf.getvalue()).decode('utf-8')
    
    except Exception as e:
        print(f"Error: {str(e)}")
        return None

#FUNCIÓN PRINCIPAL

l = df_f[['buildUpPlaySpeed', 'buildUpPlayDribbling', 'buildUpPlayPassing', 'chanceCreationPassing', 'chanceCreationCrossing', 'chanceCreationShooting', 'defencePressure', 'defenceAggression', 'defenceTeamWidth' ]]
def generate_team_report(df, team_name, years):
    try:
        team_data = df[df['team_long_name'] == team_name].iloc[0]
        metrics = [col for col in l.columns if isinstance(team_data[col], (list, np.ndarray))]

        html = f"""
        <style>
            .compact-report {{
                width: {CONFIG["table_style"]["width"]};
                max-width: 500px;
                border-collapse: collapse;
                margin: 0 auto;
                font-family: Arial;
                table-layout: fixed;
            }}
            .compact-report th {{
                background-color: {CONFIG["table_style"]["header_bg"]};
                color: {CONFIG["table_style"]["header_text"]};
                padding: 12px;
                text-align: left;
                font-size: 16px;
                border: {CONFIG["table_style"]["border"]};
                position: sticky;
                top: 0;
            }}
            .compact-report td {{
                padding: {CONFIG["table_style"]["cell_padding"]};
                border: {CONFIG["table_style"]["border"]};
                vertical-align: left;
            }}
            .metric-column {{
                width: 60%;
                text-align: left;
                font-size: 14px;
                padding-left: 15px;
            }}
            .sparkline-column {{
                width: 40%;
                text-align: center;
            }}
            .sparkline-img {{
                max-width: 100%;
                height: auto;
                display: block;
                margin: 0 auto;
            }}
        </style>
        <table class='compact-report'>
            <thead>
                <tr>
                    <th colspan="2" style="font-size: 18px;text-align: center">{team_name.upper()}</th>
                </tr>
                <tr>
                    <th class="metric-column" style="font-size: 18px;text-align: center">METRIC</th>
                    <th class="sparkline-column" style="font-size: 18px;text-align: center">6 YEARS TREND</th>
                </tr>
            </thead>
            <tbody>
        """

        def format_metric_name(metric_name):
            import re
            formatted = re.sub(r'(?<=[a-z])(?=[A-Z])', ' ', metric_name)
            return formatted.title()

        for metric in metrics:
            sparkline_b64 = create_sparkline(team_data[metric], years)
            sparkline_html = f'<img class="sparkline-img" src="data:image/png;base64,{sparkline_b64}">' if sparkline_b64 else "No data"
            metric_display = format_metric_name(metric)
            
            html += f"""
            <tr>
                <td class="metric-column">{metric_display}</td>
                <td class="sparkline-column">{sparkline_html}</td>
            </tr>
            """
        
        html += "</tbody></table>"
        return HTML(html)
    
    except Exception as e:
        return HTML(f"<p style='color:red; font-size:12px;'>Error generating report: {str(e)}</p>")

# Ejecución
YEARS = ['09/10', '10/11', '11/12', '12/13', '13/14', '14/15']
TEAM = "Real Madrid CF"

report = generate_team_report(df_f, TEAM, YEARS)
display(report)
with open("table.html", "w") as f:
    f.write(generate_team_report(df_f, "Real Madrid CF", YEARS).data)
# Out:
#         <style>
#             .compact-report {
#                 width: 100%;
#                 max-width: 500px;
#                 border-collapse: collapse;
#                 margin: 0 auto;
#                 font-family: Arial;
#                 table-layout: fixed;
#             }
#             .compact-report th {
#                 background-color: #2C3E50;
#                 color: white;
#                 padding: 12px;
#                 text-align: left;
#                 font-size: 16px;
#                 border: 1px solid #ddd;
#                 position: sticky;
#                 top: 0;
#             }
#             .compact-report td {
#                 padding: 8px;
#                 border: 1px solid #ddd;
#                 vertical-align: left;
#             }
#             .metric-column {
#                 width: 60%;
#                 text-align: left;
#                 font-size: 14px;
#                 padding-left: 15px;
#             }
#             .sparkline-column {
#                 width: 40%;
#                 text-align: center;
#             }
#             .sparkline-img {
#                 max-width: 100%;
#                 height: auto;
#                 display: block;
#                 margin: 0 auto;
#             }
#         </style>
#         <table class='compact-report'>
#             <thead>
#                 <tr>
#                     <th colspan="2" style="font-size: 18px;text-align: center">REAL MADRID CF</th>
#                 </tr>
#                 <tr>
#                     <th class="metric-column" style="font-size: 18px;text-align: center">METRIC</th>
#                     <th class="sparkline-column" style="font-size: 18px;text-align: center">6 YEARS TREND</th>
#                 </tr>
#             </thead>
#             <tbody>
#
#             <tr>
#                 <td class="metric-column">Build Up Play Speed</td>
#                 <td class="sparkline-column"><img class="sparkline-img" src="data:image/png;base64,..."></td>
#             </tr>
#
#             <tr>
#                 <td class="metric-column">Build Up Play Dribbling</td>
#                 <td class="sparkline-column"><img class="sparkline-img" src="data:image/png;base64,..."></td>
#             </tr>
#
#             <tr>
#                 <td class="metric-column">Build Up Play Passing</td>
#                 <td class="sparkline-column"><img class="sparkline-img" src="data:image/png;base64,..."></td>
#             </tr>
#
#             <tr>
#                 <td class="metric-column">Chance Creation Passing</td>
#                 <td class="sparkline-column"><img class="sparkline-img" src="data:image/png;base64,..."></td>
#             </tr>
#
#             <tr>
#                 <td class="metric-column">Chance Creation Crossing</td>
#                 <td class="sparkline-column"><img class="sparkline-img" src="data:image/png;base64,..."></td>
#             </tr>
#
#             <tr>
#                 <td class="metric-column">Chance Creation Shooting</td>
#                 <td class="sparkline-column"><img class="sparkline-img" src="data:image/png;base64,..."></td>
#             </tr>
#
#             <tr>
#                 <td class="metric-column">Defence Pressure</td>
#                 <td class="sparkline-column"><img class="sparkline-img" src="data:image/png;base64,..."></td>
#             </tr>
#
#             <tr>
#                 <td class="metric-column">Defence Aggression</td>
#                 <td class="sparkline-column"><img class="sparkline-img" src="data:image/png;base64,..."></td>
#             </tr>
#
#             <tr>
#                 <td class="metric-column">Defence Team Width</td>
#                 <td class="sparkline-column"><img class="sparkline-img" src="data:image/png;base64,..."></td>
#             </tr>
#             </tbody></table>

# %%
CONFIG = {
    "sparkline_size": (2.0, 0.5),  # Tamaño aumentado para mejor visualización
    "line_color": "#1f77b4",
    "line_width": 2,
    "dot_color": "#ff7f0e",
    "dot_size": 30,
    "bg_color": "none",
    "font_size": "14px",
    "table_style": {
        "width": "100%",
        "header_bg": "#2C3E50",
        "header_text": "white",
        "cell_padding": "8px",
        "border": "1px solid #ddd"
    }
}
#SPARKLINES

def create_sparkline(data, years):
    try:
        fig, ax = plt.subplots(figsize=CONFIG["sparkline_size"])
        fig.patch.set_alpha(0.0)  # Fondo transparente
        
        # Filtrar datos válidos
        valid_data = [y for y in data if pd.notna(y)]
        valid_years = [years[i] for i, y in enumerate(data) if pd.notna(y)]
        
        if valid_data:
            ax.plot(valid_years, valid_data, 
                   color=CONFIG["line_color"], 
                   linewidth=CONFIG["line_width"])
            ax.scatter(valid_years, valid_data, 
                      color=CONFIG["dot_color"], 
                      s=CONFIG["dot_size"])
        
        ax.axis('off')
        plt.tight_layout()
        
        buf = BytesIO()
        plt.savefig(buf, format='png', bbox_inches='tight', dpi=120)
        plt.close(fig)
        return base64.b64encode(buf.getvalue()).decode('utf-8')
    
    except Exception as e:
        print(f"Error: {str(e)}")
        return None

#FUNCIÓN PRINCIPAL

l = df_f[['buildUpPlaySpeed', 'buildUpPlayDribbling', 'buildUpPlayPassing', 'chanceCreationPassing', 'chanceCreationCrossing', 'chanceCreationShooting', 'defencePressure', 'defenceAggression', 'defenceTeamWidth' ]]
def generate_team_report(df, team_name, years):
    try:
        team_data = df[df['team_long_name'] == team_name].iloc[0]
        metrics = [col for col in l.columns if isinstance(team_data[col], (list, np.ndarray))]

        html = f"""
        <style>
            .compact-report {{
                width: {CONFIG["table_style"]["width"]};
                max-width: 500px;
                border-collapse: collapse;
                margin: 0 auto;
                font-family: Arial;
                table-layout: fixed;
            }}
            .compact-report th {{
                background-color: {CONFIG["table_style"]["header_bg"]};
                color: {CONFIG["table_style"]["header_text"]};
                padding: 12px;
                text-align: left;
                font-size: 16px;
                border: {CONFIG["table_style"]["border"]};
                position: sticky;
                top: 0;
            }}
            .compact-report td {{
                padding: {CONFIG["table_style"]["cell_padding"]};
                border: {CONFIG["table_style"]["border"]};
                vertical-align: left;
            }}
            .metric-column {{
                width: 60%;
                text-align: left;
                font-size: 14px;
                padding-left: 15px;
            }}
            .sparkline-column {{
                width: 40%;
                text-align: center;
            }}
            .sparkline-img {{
                max-width: 100%;
                height: auto;
                display: block;
                margin: 0 auto;
            }}
        </style>
        <table class='compact-report'>
            <thead>
                <tr>
                    <th colspan="2" style="font-size: 18px;text-align: center">{team_name.upper()}</th>
                </tr>
                <tr>
                    <th class="metric-column" style="font-size: 18px;text-align: center">METRIC</th>
                    <th class="sparkline-column" style="font-size: 18px;text-align: center">6 YEARS TREND</th>
                </tr>
            </thead>
            <tbody>
        """

        def format_metric_name(metric_name):
            import re
            formatted = re.sub(r'(?<=[a-z])(?=[A-Z])', ' ', metric_name)
            return formatted.title()

        for metric in metrics:
            sparkline_b64 = create_sparkline(team_data[metric], years)
            sparkline_html = f'<img class="sparkline-img" src="data:image/png;base64,{sparkline_b64}">' if sparkline_b64 else "No data"
            metric_display = format_metric_name(metric)
            
            html += f"""
            <tr>
                <td class="metric-column">{metric_display}</td>
                <td class="sparkline-column">{sparkline_html}</td>
            </tr>
            """
        
        html += "</tbody></table>"
        return HTML(html)
    
    except Exception as e:
        return HTML(f"<p style='color:red; font-size:12px;'>Error generating report: {str(e)}</p>")

# Ejecución
YEARS = ['09/10', '10/11', '11/12', '12/13', '13/14', '14/15']
TEAM = "Atlético Madrid"

report = generate_team_report(df_f, TEAM, YEARS)
display(report)
with open("table.html", "w") as f:
    f.write(generate_team_report(df_f, "Atlético Madrid", YEARS).data)
# Out:
#         <style>
#             .compact-report {
#                 width: 100%;
#                 max-width: 500px;
#                 border-collapse: collapse;
#                 margin: 0 auto;
#                 font-family: Arial;
#                 table-layout: fixed;
#             }
#             .compact-report th {
#                 background-color: #2C3E50;
#                 color: white;
#                 padding: 12px;
#                 text-align: left;
#                 font-size: 16px;
#                 border: 1px solid #ddd;
#                 position: sticky;
#                 top: 0;
#             }
#             .compact-report td {
#                 padding: 8px;
#                 border: 1px solid #ddd;
#                 vertical-align: left;
#             }
#             .metric-column {
#                 width: 60%;
#                 text-align: left;
#                 font-size: 14px;
#                 padding-left: 15px;
#             }
#             .sparkline-column {
#                 width: 40%;
#                 text-align: center;
#             }
#             .sparkline-img {
#                 max-width: 100%;
#                 height: auto;
#                 display: block;
#                 margin: 0 auto;
#             }
#         </style>
#         <table class='compact-report'>
#             <thead>
#                 <tr>
#                     <th colspan="2" style="font-size: 18px;text-align: center">ATLÉTICO MADRID</th>
#                 </tr>
#                 <tr>
#                     <th class="metric-column" style="font-size: 18px;text-align: center">METRIC</th>
#                     <th class="sparkline-column" style="font-size: 18px;text-align: center">6 YEARS TREND</th>
#                 </tr>
#             </thead>
#             <tbody>
#
#             <tr>
#                 <td class="metric-column">Build Up Play Speed</td>
#                 <td class="sparkline-column"><img class="sparkline-img" src="data:image/png;base64,..."></td>
#             </tr>
#
#             <tr>
#                 <td class="metric-column">Build Up Play Dribbling</td>
#                 <td class="sparkline-column"><img class="sparkline-img" src="data:image/png;base64,..."></td>
#             </tr>
#
#             <tr>
#                 <td class="metric-column">Build Up Play Passing</td>
#                 <td class="sparkline-column"><img class="sparkline-img" src="data:image/png;base64,..."></td>
#             </tr>
#
#             <tr>
#                 <td class="metric-column">Chance Creation Passing</td>
#                 <td class="sparkline-column"><img class="sparkline-img" src="data:image/png;base64,..."></td>
#             </tr>
#
#             <tr>
#                 <td class="metric-column">Chance Creation Crossing</td>
#                 <td class="sparkline-column"><img class="sparkline-img" src="data:image/png;base64,..."></td>
#             </tr>
#
#             <tr>
#                 <td class="metric-column">Chance Creation Shooting</td>
#                 <td class="sparkline-column"><img class="sparkline-img" src="data:image/png;base64,..."></td>
#             </tr>
#
#             <tr>
#                 <td class="metric-column">Defence Pressure</td>
#                 <td class="sparkline-column"><img class="sparkline-img" src="data:image/png;base64,..."></td>
#             </tr>
#
#             <tr>
#                 <td class="metric-column">Defence Aggression</td>
#                 <td class="sparkline-column"><img class="sparkline-img" src="data:image/png;base64,..."></td>
#             </tr>
#
#             <tr>
#                 <td class="metric-column">Defence Team Width</td>
#                 <td class="sparkline-column"><img class="sparkline-img" src="data:image/png;base64,..."></td>
#             </tr>
#             </tbody></table>

# %% [markdown]
# # CREACIÓN DE GRÁFICOS PARA LAS TENDENCIAS DE JUEGO

# %% [markdown]
# ## BUPS

# %%
# ATENCIÓN CAMBIAR EL _BUPS PARA SU HOMOLOGO EN CADA DF!!!
df_bups = df_f[['team_long_name','BUPS-TEMPORADA 09/10',	'BUPS-TEMPORADA 10/11',	'BUPS-TEMPORADA 11/12',	'BUPS-TEMPORADA 12/13',	'BUPS-TEMPORADA 13/14',	'BUPS-TEMPORADA 14/15']]

l = ["09/10","10/11","11/12","12/13","13/14","14/15"]
# Suponiendo que df_f tiene equipos como filas y años como columnas
# Convertir el DataFrame a formato largo
df_bups2 = df_bups.melt(id_vars=["team_long_name"], var_name="Temporada", value_name="Valor") #["team_long_name"]

# Crear el gráfico de líneas
plt.figure(figsize=(50, 25))
bups = sns.lineplot(data=df_bups2, x="Temporada", y="Valor", hue="team_long_name", marker="o")

# Personalizar gráfico
plt.xlabel("Temporada",fontsize=64,labelpad = 50)
plt.ylabel("Build Up Play Speed",fontsize=64,labelpad = 30)

# Etiquetas personalizadas
plt.xticks(ticks=range(len(l)),labels=l,fontsize=34,rotation=70,ha='right',rotation_mode='anchor')
#Toquetear el eje y
import numpy as np
bups.invert_yaxis()
# Definir rango del eje Y
plt.ylim(20, 80)

# Número de divisiones deseado
num_divisiones = 6  

# Generar los valores de las marcas (ticks)
yticks = np.linspace(20, 80, num_divisiones)  

# Aplicar las marcas al eje Y
plt.yticks(yticks)
plt.title(" Evolución del Build Up Play Speed por Temporadas",fontsize=74)
plt.legend(title="Equipos",fontsize=25,title_fontsize=54, loc="center left", bbox_to_anchor=(-0.24,0.5),borderaxespad=0.)
plt.xticks(fontsize=34,rotation=70,ha = 'right',rotation_mode='anchor') # Rotar etiquetas si hay muchos años
plt.yticks(fontsize=44,rotation=0)
plt.subplots_adjust(bottom=0.15)
#plt.margins(x=0.4)
#plt.subplots_adjust(left=0.05, right=0.75)
plt.grid(True)

# %% [markdown]
# ## BUPD

# %%
# ATENCIÓN CAMBIAR EL _BUPS PARA SU HOMOLOGO EN CADA DF!!!
df_bups = df_f[['team_long_name','BUPD-TEMPORADA 09/10',	'BUPD-TEMPORADA 10/11',	'BUPD-TEMPORADA 11/12',	'BUPD-TEMPORADA 12/13',	'BUPD-TEMPORADA 13/14',	'BUPD-TEMPORADA 14/15']]

l = ["09/10","10/11","11/12","12/13","13/14","14/15"]
# Suponiendo que df_f tiene equipos como filas y años como columnas
# Convertir el DataFrame a formato largo
df_bups2 = df_bups.melt(id_vars=["team_long_name"], var_name="Temporada", value_name="Valor") #["team_long_name"]

# Crear el gráfico de líneas
plt.figure(figsize=(50, 25))
bups = sns.lineplot(data=df_bups2, x="Temporada", y="Valor", hue="team_long_name", marker="o")

# Personalizar gráfico
plt.xlabel("Temporada",fontsize=64,labelpad = 50)
plt.ylabel("Build Up Play Dribbling",fontsize=64,labelpad = 30)

# Etiquetas personalizadas
plt.xticks(ticks=range(len(l)),labels=l,fontsize=34,rotation=70,ha='right',rotation_mode='anchor')
#Toquetear el eje y
import numpy as np
bups.invert_yaxis()
# Definir rango del eje Y
plt.ylim(20, 80)

# Número de divisiones deseado
num_divisiones = 6  

# Generar los valores de las marcas (ticks)
yticks = np.linspace(20, 80, num_divisiones)  

# Aplicar las marcas al eje Y
plt.yticks(yticks)
plt.title(" Evolución del Build Up Play Dribbling por Temporadas",fontsize=74)
plt.legend(title="Equipos",fontsize=25,title_fontsize=54, loc="center left", bbox_to_anchor=(-0.24,0.5),borderaxespad=0.)
plt.xticks(fontsize=34,rotation=70,ha = 'right',rotation_mode='anchor') # Rotar etiquetas si hay muchos años
plt.yticks(fontsize=44,rotation=0)
plt.subplots_adjust(bottom=0.15)
#plt.margins(x=0.4)
#plt.subplots_adjust(left=0.05, right=0.75)
plt.grid(True)

# %% [markdown]
# ## BUPP

# %%
# ATENCIÓN CAMBIAR EL _BUPS PARA SU HOMOLOGO EN CADA DF!!!
df_bups = df_f[['team_long_name','BUPP-TEMPORADA 09/10',	'BUPP-TEMPORADA 10/11',	'BUPP-TEMPORADA 11/12',	'BUPP-TEMPORADA 12/13',	'BUPP-TEMPORADA 13/14',	'BUPP-TEMPORADA 14/15']]

l = ["09/10","10/11","11/12","12/13","13/14","14/15"]
# Suponiendo que df_f tiene equipos como filas y años como columnas
# Convertir el DataFrame a formato largo
df_bups2 = df_bups.melt(id_vars=["team_long_name"], var_name="Temporada", value_name="Valor") #["team_long_name"]

# Crear el gráfico de líneas
plt.figure(figsize=(50, 25))
bups = sns.lineplot(data=df_bups2, x="Temporada", y="Valor", hue="team_long_name", marker="o")

# Personalizar gráfico
plt.xlabel("Temporada",fontsize=64,labelpad = 50)
plt.ylabel("Build Up Play Passing",fontsize=64,labelpad = 30)

# Etiquetas personalizadas
plt.xticks(ticks=range(len(l)),labels=l,fontsize=34,rotation=70,ha='right',rotation_mode='anchor')
#Toquetear el eje y
import numpy as np
bups.invert_yaxis()
# Definir rango del eje Y
plt.ylim(20, 80)

# Número de divisiones deseado
num_divisiones = 6  

# Generar los valores de las marcas (ticks)
yticks = np.linspace(20, 80, num_divisiones)  

# Aplicar las marcas al eje Y
plt.yticks(yticks)
plt.title(" Evolución del Build Up Play Passing por Temporadas",fontsize=74)
plt.legend(title="Equipos",fontsize=25,title_fontsize=54, loc="center left", bbox_to_anchor=(-0.24,0.5),borderaxespad=0.)
plt.xticks(fontsize=34,rotation=70,ha = 'right',rotation_mode='anchor') # Rotar etiquetas si hay muchos años
plt.yticks(fontsize=44,rotation=0)
plt.subplots_adjust(bottom=0.15)
#plt.margins(x=0.4)
#plt.subplots_adjust(left=0.05, right=0.75)
plt.grid(True)

# %% [markdown]
# ## CCP

# %%
# ATENCIÓN CAMBIAR EL _BUPS PARA SU HOMOLOGO EN CADA DF!!!
df_bups = df_f[['team_long_name','CCP-TEMPORADA 09/10',	'CCP-TEMPORADA 10/11',	'CCP-TEMPORADA 11/12',	'CCP-TEMPORADA 12/13',	'CCP-TEMPORADA 13/14',	'CCP-TEMPORADA 14/15']]

l = ["09/10","10/11","11/12","12/13","13/14","14/15"]
# Suponiendo que df_f tiene equipos como filas y años como columnas
# Convertir el DataFrame a formato largo
df_bups2 = df_bups.melt(id_vars=["team_long_name"], var_name="Temporada", value_name="Valor") #["team_long_name"]

# Crear el gráfico de líneas
plt.figure(figsize=(50, 25))
bups = sns.lineplot(data=df_bups2, x="Temporada", y="Valor", hue="team_long_name", marker="o")

# Personalizar gráfico
plt.xlabel("Temporada",fontsize=64,labelpad = 50)
plt.ylabel("Chance Creation Passing",fontsize=64,labelpad = 30)

# Etiquetas personalizadas
plt.xticks(ticks=range(len(l)),labels=l,fontsize=34,rotation=70,ha='right',rotation_mode='anchor')
#Toquetear el eje y
import numpy as np
bups.invert_yaxis()
# Definir rango del eje Y
plt.ylim(20, 80)

# Número de divisiones deseado
num_divisiones = 6  

# Generar los valores de las marcas (ticks)
yticks = np.linspace(20, 80, num_divisiones)  

# Aplicar las marcas al eje Y
plt.yticks(yticks)
plt.title(" Evolución del Chance Creation Passing por Temporadas",fontsize=74)
plt.legend(title="Equipos",fontsize=25,title_fontsize=54, loc="center left", bbox_to_anchor=(-0.24,0.5),borderaxespad=0.)
plt.xticks(fontsize=34,rotation=70,ha = 'right',rotation_mode='anchor') # Rotar etiquetas si hay muchos años
plt.yticks(fontsize=44,rotation=0)
plt.subplots_adjust(bottom=0.15)
#plt.margins(x=0.4)
#plt.subplots_adjust(left=0.05, right=0.75)
plt.grid(True)

# %% [markdown]
# ## CCC

# %%
# ATENCIÓN CAMBIAR EL _BUPS PARA SU HOMOLOGO EN CADA DF!!!
df_bups = df_f[['team_long_name','CCC-TEMPORADA 09/10',	'CCC-TEMPORADA 10/11',	'CCC-TEMPORADA 11/12',	'CCC-TEMPORADA 12/13',	'CCC-TEMPORADA 13/14',	'CCC-TEMPORADA 14/15']]

l = ["09/10","10/11","11/12","12/13","13/14","14/15"]
# Suponiendo que df_f tiene equipos como filas y años como columnas
# Convertir el DataFrame a formato largo
df_bups2 = df_bups.melt(id_vars=["team_long_name"], var_name="Temporada", value_name="Valor") #["team_long_name"]

# Crear el gráfico de líneas
plt.figure(figsize=(50, 25))
bups = sns.lineplot(data=df_bups2, x="Temporada", y="Valor", hue="team_long_name", marker="o")

# Personalizar gráfico
plt.xlabel("Temporada",fontsize=64,labelpad = 50)
plt.ylabel("Chance Creation Crossing",fontsize=64,labelpad = 30)

# Etiquetas personalizadas
plt.xticks(ticks=range(len(l)),labels=l,fontsize=34,rotation=70,ha='right',rotation_mode='anchor')
#Toquetear el eje y
import numpy as np
bups.invert_yaxis()
# Definir rango del eje Y
plt.ylim(20, 80)

# Número de divisiones deseado
num_divisiones = 6  

# Generar los valores de las marcas (ticks)
yticks = np.linspace(20, 80, num_divisiones)  

# Aplicar las marcas al eje Y
plt.yticks(yticks)
plt.title(" Evolución del Chance Creation Crossing por Temporadas",fontsize=74)
plt.legend(title="Equipos",fontsize=25,title_fontsize=54, loc="center left", bbox_to_anchor=(-0.24,0.5),borderaxespad=0.)
plt.xticks(fontsize=34,rotation=70,ha = 'right',rotation_mode='anchor') # Rotar etiquetas si hay muchos años
plt.yticks(fontsize=44,rotation=0)
plt.subplots_adjust(bottom=0.15)
#plt.margins(x=0.4)
#plt.subplots_adjust(left=0.05, right=0.75)
plt.grid(True)

# %% [markdown]
# ## CCS

# %%
# ATENCIÓN CAMBIAR EL _BUPS PARA SU HOMOLOGO EN CADA DF!!!
df_bups = df_f[['team_long_name','CCS-TEMPORADA 09/10',	'CCS-TEMPORADA 10/11',	'CCS-TEMPORADA 11/12',	'CCS-TEMPORADA 12/13',	'CCS-TEMPORADA 13/14',	'CCS-TEMPORADA 14/15']]

l = ["09/10","10/11","11/12","12/13","13/14","14/15"]
# Suponiendo que df_f tiene equipos como filas y años como columnas
# Convertir el DataFrame a formato largo
df_bups2 = df_bups.melt(id_vars=["team_long_name"], var_name="Temporada", value_name="Valor") #["team_long_name"]

# Crear el gráfico de líneas
plt.figure(figsize=(50, 25))
bups = sns.lineplot(data=df_bups2, x="Temporada", y="Valor", hue="team_long_name", marker="o")

# Personalizar gráfico
plt.xlabel("Temporada",fontsize=64,labelpad = 50)
plt.ylabel("Chance Creation Shooting",fontsize=64,labelpad = 30)

# Etiquetas personalizadas
plt.xticks(ticks=range(len(l)),labels=l,fontsize=34,rotation=70,ha='right',rotation_mode='anchor')
#Toquetear el eje y
import numpy as np
bups.invert_yaxis()
# Definir rango del eje Y
plt.ylim(20, 80)

# Número de divisiones deseado
num_divisiones = 6  

# Generar los valores de las marcas (ticks)
yticks = np.linspace(20, 80, num_divisiones)  

# Aplicar las marcas al eje Y
plt.yticks(yticks)
plt.title(" Evolución del Chance Creation Shooting por Temporadas",fontsize=74)
plt.legend(title="Equipos",fontsize=25,title_fontsize=54, loc="center left", bbox_to_anchor=(-0.24,0.5),borderaxespad=0.)
plt.xticks(fontsize=34,rotation=70,ha = 'right',rotation_mode='anchor') # Rotar etiquetas si hay muchos años
plt.yticks(fontsize=44,rotation=0)
plt.subplots_adjust(bottom=0.15)
#plt.margins(x=0.4)
#plt.subplots_adjust(left=0.05, right=0.75)
plt.grid(True)

# %% [markdown]
# ## DP

# %%
#  ATENCIÓN CAMBIAR EL _BUPS PARA SU HOMOLOGO EN CADA DF!!!
df_bups = df_f[['team_long_name','DP-TEMPORADA 09/10',	'DP-TEMPORADA 10/11',	'DP-TEMPORADA 11/12',	'DP-TEMPORADA 12/13',	'DP-TEMPORADA 13/14',	'DP-TEMPORADA 14/15']]

l = ["09/10","10/11","11/12","12/13","13/14","14/15"]
# Suponiendo que df_f tiene equipos como filas y años como columnas
# Convertir el DataFrame a formato largo
df_bups2 = df_bups.melt(id_vars=["team_long_name"], var_name="Temporada", value_name="Valor") #["team_long_name"]

# Crear el gráfico de líneas
plt.figure(figsize=(50, 25))
bups = sns.lineplot(data=df_bups2, x="Temporada", y="Valor", hue="team_long_name", marker="o")

# Personalizar gráfico
plt.xlabel("Temporada",fontsize=64,labelpad = 50)
plt.ylabel("Defence Pressure",fontsize=64,labelpad = 30)

# Etiquetas personalizadas
plt.xticks(ticks=range(len(l)),labels=l,fontsize=34,rotation=70,ha='right',rotation_mode='anchor')
#Toquetear el eje y
import numpy as np
bups.invert_yaxis()
# Definir rango del eje Y
plt.ylim(20, 80)

# Número de divisiones deseado
num_divisiones = 6  

# Generar los valores de las marcas (ticks)
yticks = np.linspace(20, 80, num_divisiones)  

# Aplicar las marcas al eje Y
plt.yticks(yticks)
plt.title(" Evolución del Defence Pressure por Temporadas",fontsize=74)
plt.legend(title="Equipos",fontsize=25,title_fontsize=54, loc="center left", bbox_to_anchor=(-0.24,0.5),borderaxespad=0.)
plt.xticks(fontsize=34,rotation=70,ha = 'right',rotation_mode='anchor') # Rotar etiquetas si hay muchos años
plt.yticks(fontsize=44,rotation=0)
plt.subplots_adjust(bottom=0.15)
#plt.margins(x=0.4)
#plt.subplots_adjust(left=0.05, right=0.75)
plt.grid(True)

# %% [markdown]
# ## DA

# %%
#  ATENCIÓN CAMBIAR EL _BUPS PARA SU HOMOLOGO EN CADA DF!!!
df_bups = df_f[['team_long_name','DA-TEMPORADA 09/10',	'DA-TEMPORADA 10/11',	'DA-TEMPORADA 11/12',	'DA-TEMPORADA 12/13',	'DA-TEMPORADA 13/14',	'DA-TEMPORADA 14/15']]

l = ["09/10","10/11","11/12","12/13","13/14","14/15"]
# Suponiendo que df_f tiene equipos como filas y años como columnas
# Convertir el DataFrame a formato largo
df_bups2 = df_bups.melt(id_vars=["team_long_name"], var_name="Temporada", value_name="Valor") #["team_long_name"]

# Crear el gráfico de líneas
plt.figure(figsize=(50, 25))
bups = sns.lineplot(data=df_bups2, x="Temporada", y="Valor", hue="team_long_name", marker="o")

# Personalizar gráfico
plt.xlabel("Temporada",fontsize=64,labelpad = 50)
plt.ylabel("Defence Aggression",fontsize=64,labelpad = 30)

# Etiquetas personalizadas
plt.xticks(ticks=range(len(l)),labels=l,fontsize=34,rotation=70,ha='right',rotation_mode='anchor')
#Toquetear el eje y
import numpy as np
bups.invert_yaxis()
# Definir rango del eje Y
plt.ylim(20, 80)

# Número de divisiones deseado
num_divisiones = 6  

# Generar los valores de las marcas (ticks)
yticks = np.linspace(20, 80, num_divisiones)  

# Aplicar las marcas al eje Y
plt.yticks(yticks)
plt.title(" Evolución del Defence Agression por Temporadas",fontsize=74)
plt.legend(title="Equipos",fontsize=25,title_fontsize=54, loc="center left", bbox_to_anchor=(-0.24,0.5),borderaxespad=0.)
plt.xticks(fontsize=34,rotation=70,ha = 'right',rotation_mode='anchor') # Rotar etiquetas si hay muchos años
plt.yticks(fontsize=44,rotation=0)
plt.subplots_adjust(bottom=0.15)
#plt.margins(x=0.4)
#plt.subplots_adjust(left=0.05, right=0.75)
plt.grid(True)

# %% [markdown]
# ## DTW

# %%
#  ATENCIÓN CAMBIAR EL _BUPS PARA SU HOMOLOGO EN CADA DF!!!                                  
df_bups = df_f[['team_long_name','DTW-TEMPORADA 09/10',	'DTW-TEMPORADA 10/11',	'DTW-TEMPORADA 11/12',	'DTW-TEMPORADA 12/13',	'DTW-TEMPORADA 13/14',	'DTW-TEMPORADA 14/15']]

l = ["09/10","10/11","11/12","12/13","13/14","14/15"]
# Suponiendo que df_f tiene equipos como filas y años como columnas
# Convertir el DataFrame a formato largo
df_bups2 = df_bups.melt(id_vars=["team_long_name"], var_name="Temporada", value_name="Valor") #["team_long_name"]

# Crear el gráfico de líneas
plt.figure(figsize=(50, 25))
bups = sns.lineplot(data=df_bups2, x="Temporada", y="Valor", hue="team_long_name", marker="o")

# Personalizar gráfico
plt.xlabel("Temporada",fontsize=64,labelpad = 50)
plt.ylabel("Defence Team Width",fontsize=64,labelpad = 30)

# Etiquetas personalizadas
plt.xticks(ticks=range(len(l)),labels=l,fontsize=34,rotation=70,ha='right',rotation_mode='anchor')
#Toquetear el eje y
import numpy as np
bups.invert_yaxis()
# Definir rango del eje Y
plt.ylim(20, 80)

# Número de divisiones deseado
num_divisiones = 6  

# Generar los valores de las marcas (ticks)
yticks = np.linspace(20, 80, num_divisiones)  

# Aplicar las marcas al eje Y
plt.yticks(yticks)
plt.title(" Evolución del Defence Team Width por Temporadas",fontsize=74)
plt.legend(title="Equipos",fontsize=25,title_fontsize=54, loc="center left", bbox_to_anchor=(-0.24,0.5),borderaxespad=0.)
plt.xticks(fontsize=34,rotation=70,ha = 'right',rotation_mode='anchor') # Rotar etiquetas si hay muchos años
plt.yticks(fontsize=44,rotation=0)
plt.subplots_adjust(bottom=0.15)
#plt.margins(x=0.4)
#plt.subplots_adjust(left=0.05, right=0.75)
plt.grid(True)
